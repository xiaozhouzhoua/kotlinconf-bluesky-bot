// %% [markdown]
// # Filtering JetStream Events

// %% [markdown]
// In this notebook, we'll filter events from the Redis Stream that we created in the previous notebook. We'll use a combination of techniques to filter the events:
//
// 1. Deduplication using Redis Bloom Filter to avoid processing the same event multiple times
// 2. Content-based filtering using a machine learning model to identify software-related posts
// 3. Storing filtered events in Redis for further processing
//
// Redis Bloom Filter is a probabilistic data structure that allows us to check if an element is in a set. It's very memory efficient and has a constant time complexity for both insertion and lookup operations. The trade-off is that it can have false positives, but the probability of false positives can be controlled by the size of the filter.
//
// Machine learning models can be used to classify text into different categories. In this notebook, we'll use a pre-trained zero-shot classification model to classify posts as software-related or not.

// %% [markdown]
// ## Consuming from Redis Streams

// %% [markdown]
// ### Model Redis Streams Event
// In this section, we'll define a data class to represent the events stored in the Redis Stream. This model will be used to deserialize the events from the stream.

// %%
@file:DependsOn("redis.clients:jedis:6.0.0")

// %%
import redis.clients.jedis.resps.StreamEntry

data class Event(
    val did: String,
    val rkey: String,
    val text: String,
    val timeUs: String,
    val operation: String,
    val uri: String,
    val parentUri: String,
    val rootUri: String,
    val langs: List<String>,
) {
    companion object {
        fun fromMap(entry: StreamEntry): Event {
            val fields = entry.fields
            return Event(
                did = fields["did"] ?: "",
                rkey = fields["rkey"] ?: "",
                text = fields["text"] ?: "",
                timeUs = fields["timeUs"] ?: "",
                operation = fields["operation"] ?: "",
                uri = fields["uri"] ?: "",
                parentUri = fields["parentUri"] ?: "",
                rootUri = fields["rootUri"] ?: "",
                langs = fields["langs"]?.replace("[", "")?.replace("]", "")?.split(", ") ?: emptyList()
            )
        }
    }
}

// %% [markdown]
// ### Creating a Redis Client
// Create a Jedis client to connect to Redis. This is a reusable client that can be used to interact with Redis Streams.

// %%
import redis.clients.jedis.JedisPooled

val jedisPooled = JedisPooled()

// %% [markdown]
// ### Creating a Consumer Group
// Create a consumer group to read from the Redis Stream. A consumer group allows multiple consumers to read from the same stream without duplicating the work. Each consumer in the group will receive a different subset of the messages.
//
// A consumer group can be created in Redis with the XGROUP CREATE command:
//
// `XGROUP CREATE streamName groupName id [MKSTREAM]`
//
// To create a consumer group in this notebook, we will encapsulate the command in a function. The function will take the stream name and the group name as parameters.

// %%
import redis.clients.jedis.StreamEntryID

fun createConsumerGroup(streamName: String, consumerGroupName: String) {
    try {
        jedisPooled.xgroupCreate(streamName, consumerGroupName, StreamEntryID("0-0"), true)
    } catch (_: Exception) {
        println("Group already exists")
    }
}

// %%
createConsumerGroup("jetstream", "printer-example")

// %% [markdown]
// ### Reading from the Stream
// Create a reusable function to read from the stream. This function will read from the stream and return a list of entries. It uses the XREADGROUP command to read from the stream as part of a consumer group:
//
// `XREADGROUP GROUP groupName consumerName COUNT count BLOCK blockTime streamName id`
//
// The command will be encapsulated in a function that takes the stream name, consumer group name, consumer name, and count as parameters. The function will return a list of entries.

// %%
import redis.clients.jedis.params.XReadGroupParams

fun readFromStream(
    streamName: String,
    consumerGroup: String,
    consumer: String, count: Int
): List<Map.Entry<String, List<StreamEntry>>> {
    return jedisPooled.xreadGroup(
        consumerGroup,
        consumer,
        XReadGroupParams().count(count),
        mapOf(
            streamName to StreamEntryID.XREADGROUP_UNDELIVERED_ENTRY
        )
    ) ?: emptyList()
}

// %% [markdown]
// ### Acknowledging Messages
// Create a function to acknowledge the message. This is important to let Redis know that the message has been processed successfully, so it won't be delivered to other consumers in the group.
//
// This is done by using the XACK command:
//
// `XACK streamName groupName id`
//
// The command will be encapsulated in a lambda function that takes the stream name, consumer group name, and entry as parameters. The function will acknowledge the message by calling the XACK command.

// %%
fun ackFunction(): (String, String, StreamEntry) -> Unit {
    return { streamName, consumerGroup, entry ->
        jedisPooled.xack(
            streamName,
            consumerGroup,
            entry.id
        )
    }
}

// %% [markdown]
// ### Consuming the Stream
// Create a reusable function to consume the stream.
//
// This function implements a pipeline pattern where each event is processed sequentially by a series of handlers. If any handler returns false, the processing stops for that event.
//
// After processing the event, the function acknowledges the message using the ack function.

// %%
%use coroutines

// %%
import kotlinx.coroutines.*

fun consumeStream(
    streamName: String,
    consumerGroup: String,
    consumer: String,
    handlers: List<(Event) -> Pair<Boolean, String>>,
    ackFunction: ((String, String, StreamEntry) -> Unit),
    count: Int = 5,
    limit: Int = 5
) {
    var lastMessageTime = System.currentTimeMillis()
    var consumed = 0

    while (consumed < limit) {
        val entries = readFromStream(streamName, consumerGroup, consumer, count)
        val allEntries = entries.flatMap { it.value }
        allEntries.map { entry ->
            consumed++
            val event = Event.fromMap(entry)

            for (handler in handlers) {
                val (shouldContinue, message) = handler(event)
                ackFunction(streamName, consumerGroup, entry)

                if (!shouldContinue) {
                    println("$consumer: Handler stopped processing: $message")
                    break
                }
            }
        }

        if (allEntries.isEmpty()) {
            val now = System.currentTimeMillis()
            if (now - lastMessageTime >= 2_000) {
                println("$consumer: No new messages for 2 seconds. Stopping.")
                break
            }
        }
    }

}

// %% [markdown]
// To test the consumeStream function, we'll create a simple handler that prints the event's URI.

// %%
val printUri: (Event) -> Pair<Boolean, String> = {
    println("Got event from ${it.uri}")
    Pair(true, "OK")
}

// %%
runBlocking {
    consumeStream(
        streamName = "jetstream",
        consumerGroup = "printer-example",
        consumer ="printer-1",
        handlers = listOf(printUri),
        ackFunction = ackFunction(),
        count = 100,
        limit = 200
    )
}
// Out:
// Got event from at://did:plc:yuer2kud23jb3c7eq7khnqqb/app.bsky.feed.post/3lpygox6xw22o
// Got event from at://did:plc:tfkomiidtoc22higi34kxkdr/app.bsky.feed.post/3lpygpaq4ks23
// Got event from at://did:plc:dhblt3knvhtxrxqijrjhlnoj/app.bsky.feed.post/3lpygpbwqvc2q
// Got event from at://did:plc:ojrjl55nrxb7op5rdm3rjvue/app.bsky.feed.post/3lpygpaxjuk26
// Got event from at://did:plc:vlba54vik27uhaoyysup6yqo/app.bsky.feed.post/3lpygpbm7y22c
// Got event from at://did:plc:dd32huibi3s3xr3nbhmfrep2/app.bsky.feed.post/3lpygp3ue6s27
// Got event from at://did:plc:jhlioavkbe3r2fc4a4vgd6du/app.bsky.feed.post/3lpygpbjabk2j
// Got event from at://did:plc:7ia5gyyqv2will5wxhrdey5h/app.bsky.feed.post/3lpyg
// Got event from at://did:plc:jrcetwaiscgtlrzipjbqgqmf/app.bsky.feed.post/3lpygpbz6zc2l
// Got event from at://did:plc:47pef25n27xbumca5fdliojm/app.bsky.feed.post/3lpygpbqyd22s
// Got event from at://did:plc:u5n224ibhv7nbr3svbzy6yxx/app.bsky.feed.post/3lpygpfmx4k2s
// Got event from at://did:plc:o6ggjvnj4ze3mnrpnv5oravg/app.bsky.feed.post/3lpygpfadgs22
// Got event from at://did:plc:miueatyikzjup7r4j7cizlsm/app.bsky.feed.post/3lpygp7tofs26
// Got event from at://did:plc:on2hjrpdbvaxpkds7uapxxkv/app.bsky.feed.post/3lpygpemyns2c
// Got event from at://did:plc:olkfpj2cgwzls5tdrxf7xre5/app.bsky.feed.post/3lpygpd7sek26
// Got event from at://did:plc:mfytmhvkvd47rs6wunoucand/app.bsky.feed.post/3lpygpffjss2e
// Got event from at://did:plc:7ia5gyyqv2will5wxhrdey5h/app.bsky.feed.post/3lpygpfvm342p
// Got event from at://did:plc:bgtb7btxom2qazqfhi7z6pn5/app.bsky.feed.post/3lpygpf2gds2j

// %% [markdown]
// ## Deduplication with Bloom Filter
// Redis Bloom Filter is a probabilistic data structure that allows us to check if an element is in a set. It's very memory efficient and has a constant time complexity for both insertion and lookup operations.

// %% [markdown]
// ### Creating a Bloom Filter
// This function creates a Bloom Filter with the given name. The filter is configured with an error rate of 0.01 and an initial capacity of 1,000,000 elements.

// %%
import redis.clients.jedis.bloom.BFReserveParams
import redis.clients.jedis.exceptions.JedisDataException
fun createBloomFilter(name: String) {
    try {
        val errorRate = 0.01
        val capacity = 1_000_000L
        val reserveParams = BFReserveParams().expansion(2)
        jedisPooled.bfReserve(name, errorRate, capacity, reserveParams)
    } catch (_: JedisDataException) {
        println("Bloom filter already exists")
    }
}

// %% [markdown]
// ### Deduplication Handler
// This function creates a handler that checks if an event has already been processed by checking if its URI is in the Bloom Filter. If the URI is in the filter, the handler returns false, which stops the processing of the event.

// %%
fun deduplicate(bloomFilter: String): (Event) -> Pair<Boolean, String> {
    return { event ->
        if (jedisPooled.bfExists(bloomFilter, event.uri)) {
            Pair(false, "${event.uri} already processed")
        } else {
            Pair(true, "OK")
        }
    }
}

// %% [markdown]
// ### Atomic Acknowledgment and Bloom Filter Update
// This function creates a handler that acknowledges the message and adds the URI to the Bloom Filter in a single atomic transaction. This ensures that if the acknowledgment succeeds, the URI is also added to the filter, and vice versa.

// %%
import redis.clients.jedis.Connection
import redis.clients.jedis.JedisPool
import redis.clients.jedis.Transaction

val jedisPool = JedisPool()

fun ackAndBfFn(bloomFilter: String):  (String, String, StreamEntry) -> Unit {
    return { streamName, consumerGroup, entry ->
        jedisPool.resource.use { jedis ->
            // Create a transaction
            val multi = jedis.multi()

            // Acknowledge the message
            multi.xack(
                streamName,
                consumerGroup,
                entry.id
            )

            // Add the URI to the bloom filter
            multi.bfAdd(bloomFilter, Event.fromMap(entry).uri)

            // Execute the transaction
            multi.exec()
        }
    }
}

// %%
createConsumerGroup("jetstream", "deduplicate-example")

// %%
val bloomFilterName = "processed-uris"
createBloomFilter("processed-uris")

// %%
runBlocking {
    consumeStream(
// Got event from at://did:plc:7ia5gyyqv2will5wxhrdey5h/app.bsky.feed.post/3lpygpfloud2n
// Got event from at://did:plc:vaeiucejnplsashezfotxlxv/app.bsky.feed.post/3lpygpfi5sc23
// Got event from at://did:plc:xa6ptxdsz4dtn5vea26daolr/app.bsky.feed.post/3lpygpf6n4c24
// Got event from at://did:plc:3e33fddrg7bqchtn2wtuloix/app.bsky.feed.post/3lpygpejlbs2q
// Got event from at://did:plc:ges6ab4mwpwqlpakz6oinwab/app.bsky.feed.post/3lpygpfiik22o
// Got event from at://did:plc:yx4t3mjoaca7y4vpn5zr73m3/app.bsky.feed.post/3lpygpaj7uc24
// Got event from at://did:plc:f6sbblchfykf6dt4gcrcpf3l/app.bsky.feed.post/3lpygpfiw7k2x
// Got event from at://did:plc:x7d5gcgnr74nmt3mvw54bkag/app.bsky.feed.post/3lpygpejmb22g
// Got event from at://did:plc:rnqxosmjhw435i7mpakpajhl/app.bsky.feed.post/3lpygpfcfa22n
// Got event from at://did:plc:jrcetwaiscgtlrzipjbqgqmf/app.bsky.feed.post/3lpygpbz6zc2l
// Got event from at://did:plc:47pef25n27xbumca5fdliojm/app.bsky.feed.post/3lpygpbqyd22s
// Got event from at://did:plc:u5n224ibhv7nbr3svbzy6yxx/app.bsky.feed.post/3lpygpfmx4k2s
// Got event from at://did:plc:o6ggjvnj4ze3mnrpnv5oravg/app.bsky.feed.post/3lpygpfadgs22
// Got event from at://did:plc:miueatyikzjup7r4j7cizlsm/app.bsky.feed.post/3lpygp7tofs26
// Got event from at://did:plc:on2hjrpdbvaxpkds7uapxxkv/app.bsky.feed.post/3lpygpemyns2c
// Got event from at://did:plc:olkfpj2cgwzls5tdrxf7xre5/app.bsky.feed.post/3lpygpd7sek26
// Got event from at://did:plc:mfytmhvkvd47rs6wunoucand/app.bsky.feed.post/3lpygpffjss2e
// Got event from at://did:plc:7ia5gyyqv2will5wxhrdey5h/app.bsky.feed.post/3lpygpfvm342p
// Got event from at://did:plc:bgtb7btxom2qazqfhi7z6pn5/app.bsky.feed.post/3lpygpf2gds2j

// %% [markdown]
// ## Content-Based Filtering with Machine Learning
// In this section, we'll use a machine learning model to filter posts based on their content. We'll use a pre-trained zero-shot classification model to classify posts as software-related or not.

// %% [markdown]
// ### Setting Up the Machine Learning Model
// To load the model, we'll use the DJL (Deep Java Library) library. DJL is a high-level framework for deep learning in Java that provides a simple and consistent API for loading and using models.

// %%
@file:DependsOn("org.springframework.ai:spring-ai-redis-store:1.0.0")
@file:DependsOn("org.springframework.ai:spring-ai-transformers:1.0.0")

// %% [markdown]
// ### Creating the Model Criteria
// The criteria is used to load the model and create a predictor. The criteria specifies the model path, the engine to use (in this case, PyTorch), and the translator to use.

// %%
import org.springframework.ai.transformers.TransformersEmbeddingModel

val embeddingModel = TransformersEmbeddingModel()
embeddingModel.afterPropertiesSet()

// %% [markdown]
// ### Loading the Model
// Now we'll load the model and create a predictor. The predictor is used to make predictions with the model.

// %%
import org.springframework.ai.vectorstore.redis.RedisVectorStore
import org.springframework.ai.vectorstore.redis.RedisVectorStore.MetadataField
import redis.clients.jedis.search.Schema.FieldType

val redisVectorStore = RedisVectorStore.builder(jedisPooled, embeddingModel)
    .indexName("classifierIdx")
    .contentFieldName("text")
    .embeddingFieldName("textEmbedding")
    .prefix("classifier:")
    .initializeSchema(true)
    .vectorAlgorithm(RedisVectorStore.Algorithm.FLAT)
    .build()
redisVectorStore.afterPropertiesSet()

// %%
import kotlinx.serialization.json.Json
import org.springframework.ai.document.Document
import java.io.File
import java.util.UUID

val references = Json.decodeFromString<List<String>>(File("../resources/filtering-examples.json").readText())

fun createRouteDocument(text: String): Document {
    return Document(
        UUID.randomUUID().toString(),
        text,
        mapOf(
            "text" to text,
        )
    )
}

fun storeRouteDocumentsInRedis(references: List<String>) {
    val documents = references.map { text ->
        createRouteDocument(text)
    }

    redisVectorStore.add(documents)
}

storeRouteDocumentsInRedis(references)

// %% [markdown]
// ### Creating a Classification Function
// Now we'll create a function to classify text using the model.
//
// The function takes a text as input and returns a classification output. The classification output contains the probabilities for each candidate label.

// %%
import ai.djl.modality.nlp.translator.ZeroShotClassificationOutput
import org.springframework.ai.vectorstore.SearchRequest

fun breakSentenceIntoClauses(sentence: String): List<String> {
    return sentence.split(Regex("""[!?,.:;()"\[\]{}]+"""))
        .filter { it.isNotBlank() }.map { it.trim() }
}

fun classify(post: String): List<Double> {
    return breakSentenceIntoClauses(post).map { clause ->
        (redisVectorStore.similaritySearch(
            SearchRequest.builder()
                .topK(1)
                .query(clause)
                .build()
        )?.map { it.score ?: 0.0 } ?: emptyList())
    }.flatten()
}

// %%
fun classify(post: String): Double {
    return redisVectorStore.similaritySearch(
        SearchRequest.builder()
            .topK(1)
            .query(post)
            .build()
    )?.map { it.score }?.first() ?: 0.0
}

// %%
fun removeUrls(text: String): String {
    return text.replace(Regex("""(?:https?:\/\/)?(?:www\.)?[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(\/\S*)?"""), "")
        .replace(Regex("""@\w+"""), "")
        .replace(Regex("""\s+"""), " ")
        .trim()
}

// %%
fun classify(post: String): List<Double> {
    val cleanedPost = removeUrls(post)
    return breakSentenceIntoClauses(cleanedPost).map { clause ->
        println(clause)
        (redisVectorStore.similaritySearch(
            SearchRequest.builder()
                .topK(1)
                .query(clause)
                .build()
        )?.map {
            println("Matched sentence: ${it.text}")
            it.score ?: 0.0
        } ?: emptyList())
    }.flatten()
}

// %%
classify("Redis is a great tool for building distributed systems")
// Out:
// Redis is a great tool for building distributed systems
// Matched sentence: AI tools for devs
// [0.7052901387214661]

// %%
classify("Redis is a great tool for building applied AI systems")
// Out:
// Redis is a great tool for building applied AI systems
// Matched sentence: how to build with AI
// [0.8531131744384766]

// %% [markdown]
// ### Creating a Filter Handler
//
// Now we 'll create a handler that filters events based on their content.
//
// The handler uses the classification function to determine if a post is software -related.If the post is not software -related, the handler returns false, which stops the processing of the event.

// %%
val filter: (Event) -> Pair<Boolean, String> = { event ->
    if (event.text.isNotBlank() && event.operation != "delete") {
        val scores = classify(event.text)
        if (scores.any { it > 0.75 }) {
            Pair(true, "OK")
        } else {
            Pair(false, "Not a post related to artificial intelligence")
        }
    } else {
        Pair(false, "Text is null or empty")
    }
}

// %% [markdown]
// ## Storing Filtered Events
// In this section, we'll store the filtered events in Redis for further processing.

// %% [markdown]
// ### Converting Data Class to Hash

// %%
fun Event.toMap(): Map<String, String> {
    return mapOf(
        "did" to this.did,
        "timeUs" to this.timeUs,
        "text" to this.text,
        "langs" to this.langs.joinToString(","),
        "operation" to this.operation,
        "rkey" to this.rkey,
        "parentUri" to this.parentUri,
        "rootUri" to this.rootUri,
        "uri" to this.uri
    )
}

// %% [markdown]
// ### Storing Events in Redis
// Now we 'll create a handler that stores events in Redis. The handler stores the event as a hash in Redis, with the key being the event' s URI.

// %%
val storeEvent: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.hset("post:" + event.uri.replace("at://did:plc:", ""), event.toMap())
    Pair(true, "OK")
}

// %% [markdown]
// ### Adding Filtered Events to a New Stream
//
// Finally, we'll create a handler that adds filtered events to a new stream. This allows other consumers to process only the filtered events, rather than having to filter the events themselves.

// %%
import redis.clients.jedis.params.XAddParams

val addFilteredEventToStream: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.xadd(
        "filtered-events",
        XAddParams.xAddParams().id(StreamEntryID.NEW_ENTRY),
        event.toMap()
    )
    Pair(true, "OK")
}
createConsumerGroup("jetstream", "store-example")

// %% [markdown]
// ## Putting It All Together
// Now we 'll put all the pieces together to create a complete pipeline for filtering events from the Redis Stream.
//
// In this example we create two consumers that will process the same stream.
//
// - By doing that, we can scale the processing of the events by adding more consumers to the group.
// - Redis will make sure that each consumer will receive different messages.

// %%
runBlocking {
    listOf(
        async(Dispatchers.IO) {
            consumeStream(
                streamName = "jetstream",
                consumerGroup = "store-example",
                consumer = "store-1",
                handlers = listOf(
                    filter,
                    printUri,
                    storeEvent,
                    addFilteredEventToStream
                ),
                ackFunction = ackFunction(),
                count = 1,
                limit = 1000
            )
        },
        async(Dispatchers.IO) {
            consumeStream(
                streamName = "jetstream",
                consumerGroup = "store-example",
                consumer = "store-2", // Different consumer
                handlers = listOf(
                    filter,
                    printUri,
                    storeEvent,
                    addFilteredEventToStream
                ),
                ackFunction = ackFunction(),
                count = 1,
                limit = 1000
            )
        }
    ).awaitAll()
}
// Out:
// anatomy of a beast or just organ harvest #oc #skyoc #art
// A mí me pasa que no puedo ver las noticias porque precisamente me ahogo en todo eso como tú dices pero por suerte aquí no veo mucho porque si lo hubiera me tendría que ir jskdjd Anyway haces bien en tomarte un descanso así que dale
// Matched sentence: Is there a beginner course for understanding how these models work?
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// They know what's up ‼️
// Matched sentence: LLMs in production
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Still not sure how these AI models know so much. Feels like magic.
// Jorge Gónzalez Delivers Latin Fire On New Pop Hit ‘Sambale’
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// DEI = Diversité
// Matched sentence: Midjourney v6
// p=32893
// Matched sentence: Claude AI
// Équité
// Matched sentence: Claude AI
// Inclusion
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// 全然そんな事ないですよ！大丈夫です✌🏻🥰 新刊たのしみにしてます✨
// Matched sentence: artificial intelligence
// Le gouvernement Trump exige des entreprises américaines
// Matched sentence: Claude AI
// mais aussi étrangères si elles ont des filiales ou des contrats USA
// Matched sentence: Can’t believe how well this AI model does summarization.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// MOUNSEF WITH THE EQUALIZER
// Matched sentence: transformers architecture
// @'s No 9 scores his first goal since Aughust 31
// Matched sentence: Claude AI
// de s'engager à ne PLUS avoir de politiques DEI
// Matched sentence: GPT-4
// 2024 to bring NYCFC even
// Matched sentence: Claude AI
// Certaines ont accepté
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// notamment les GAFAM
// dedicating this one to @ #lucifer #hazbinhotel
// Matched sentence: Claude AI
// d'autres non
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Claude AI
// appreciation for the rubber ducks pattern
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I'm not bothering with any grant submissions for now
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// it's a massive spinning of wheels
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Man it is really impossible to stop people from making pet death posts to animal feeds
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// the only thing that works is strict moderation and rules which sucks
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// Heart breaking interview
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// Matched sentence: Hugging Face is the GitHub of machine learning.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// @
// This is true
// Matched sentence: why AI matters
// BI is in such a bad state that the legal minimum would be revolutionary lol Something ive been meaning to look into that you may know more about is how much ability to curtail density does the council have by refusing to expand sewer capacity and coverage
// Matched sentence: Midjourney v6
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// ‪ Honestly people think I'm wholesome so I really do just need to say more rancid shit Just because I don't depict sex doesn't mean I'm wholesome
// Matched sentence: Anthropic
// I'm not positive vibes
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Somehow my brilliant plan of using my new pole chainsaw to trim the dead branches from our tree failed to take into account the additional two hours of chopping up said branches into baggable pieces
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// I'm not a good person anyone should like or look up to
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// That kind of peace and contentment is so unique and rare
// @ Sorry to message you
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// but my children are starving and I have nothing to feed them
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Angelica works hard to give customers at the onsen the very best in customer service
// Matched sentence: AI helping me work
// Food is scarce and prices are unbearable
// Matched sentence: LLMs in production
// Please
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// It's hard work but she finds it very rewarding
// Matched sentence: Midjourney v6
// if you can help
// Matched sentence: AI helping me work
// I beg you
// Matched sentence: Learning how to prompt AI is harder than I thought.
// #AIgirl #waifu #threesome #futanari #spitroast
// Matched sentence: AI helping me work
// 😭
// Matched sentence: fun AI projects
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// null
// 💯
// Matched sentence: generative AI
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Ich sag doch
// 1977
// Matched sentence: machine learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: NLP models
// hat mir mal eine fanatische Christin erzählt
// Dead-Letter-Literal-Interpretation of the Bible Christian fundamentalism is responsible for Dementia Trump’s deconstruction of the social safety net for the poor and giving the money in tax cuts for the Rich
// Matched sentence: Claude AI
// Mich interessiert die Bibel nicht die Bohne 🤷‍♀️
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// The churches are responsible for Trump & his Fox News appointees administration
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// What % of these arrests are happening at work sites and planned immigration hearings
// Matched sentence: Meta's latest open-source vision model challenges proprietary alternatives.
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// They are all freeloaders hiding from the law
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// seguinte estarei assistindo
// Matched sentence: AI and privacy
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: AI helping me work
// Ah
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// passo mal com vcs se chamando de idoso e ainda sendo mais novo quase eu 💀
// Matched sentence: machine learning
// Thanks
// Matched sentence: Midjourney v6
// I’ll check my own feed
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: AI-generated content
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Grand meeting pour la paix à Naples
// All my life 😂😂😂
// Matched sentence: AI in everyday life
// Matched sentence: Midjourney v6
// Les peuples européens ne veulent pas de la guerre sociale camouflée en économie de guerre
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// this is why we feud
// Matched sentence: why AI matters
// for ownership rights
// Matched sentence: Claude AI
// Matched sentence: AI and privacy
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Strands #448 “Get out the dust buster
// store-2: Handler stopped processing: Text is null or empty
// Acabé entendiendo con el paso de los años
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// ” 💡🔵💡🔵 💡🔵🟡🔵 🔵 🫣😱
// Matched sentence: Midjourney v6
// y siendo ya redactora
// Matched sentence: generative AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// China's high speed train from Beijing to Shanghai is a journey of over 800 miles
// Matched sentence: runway gen-2
// que los borbones eran intocables y que gracias al servilismo de toda la prensa y sus periodistas cortesanos podían permitirse el lujo de ser en este país lo que aún hoy continúan siendo
// Matched sentence: Tried quantizing a model to run inference on CPU—speed gains are solid.
// 200 miles further than from Land's End to John o'Groats
// Matched sentence: GPT-4
// It covers that vast distance in a little over 4 hours
// Matched sentence: Midjourney v6
// unos figurines tan carísimos como carentes de
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// It was built in 3 years
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: how to build with AI
// You never really know the extremes a virus will evolve until it does
// between April 2008 and June 2011
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// We just learned that the leftover protein from the covid virus passes the blood brain barrier and directly affects human behavior
// Matched sentence: deep learning
// Puts HS2 into context
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// don't you think
// Matched sentence: AI vs humans
// It crashes serotonin and causes aggression
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// If this got extreme
// mds
// Matched sentence: LLMs in production
// Matched sentence: cool things AI can do
// who knows
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// TAMPA BAY UNITED
// Matched sentence: Still not sure how these AI models know so much. Feels like magic.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: runway gen-2
// St
// You're welcome
// Matched sentence: Tried using PyTorch instead of TensorFlow today. I think I’m converted.
// Isabella
// Matched sentence: GPT-4
// Petersburg
// Matched sentence: ChatGPT
// FL
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Midjourney v6
// How hard would it be to make a logo with a striped border
// Günün En Çok Yükselen Kripto Paraları 📈 🔹 pSTAKE Finance $PSTAKE ➡ %51 🔹 Crown by Third Time Games $CROWN ➡ %44 🔹 alright buddy $BUDDY ➡ %36 🔹 Collaterize $COLLAT ➡ %24 🔹 Purr $PURR ➡ %22
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// very
// Matched sentence: artificial intelligence
// Took me a lot of tries to make it work
// Matched sentence: trying AI for the first time
// but I found the way
// Matched sentence: AI-driven fraud detection becomes a critical tool in modern finance.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I’m still sad that Pao got hurt
// Matched sentence: I didn’t think AI could do creative stuff, but I was wrong.
// Big fan of the pattern on the home kit
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Seeing it live only makes it worse
// Matched sentence: runway gen-2
// #Nixie72
// Matched sentence: Claude AI
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// Really 🙏🏾 she will heal fast
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Friday a Federal Judge struck down an EO signed by trump that threatened penalties against the law firm Jenner & Block
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// 🏀
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// which once employed a top attorney who helped investigate the president alongside the team run by Robert S
// It was the second time a federal judge found one of trump’s orders targeting elite law firms unconstitutional
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// Mueller III
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// after another judge ruled earlier in May that an essentially identical order targeting the firm Perkins Coie appeared retributive and designed to strong-arm the firm into serving the WH
// Matched sentence: Claude AI
// who was then the special counsel
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Evaluating different rerankers after embedding retrieval. Cohere is looking promising.
// Two other firms WilmerHale and Susman Godfrey have asked for similarly decisive rulings in lawsuits they brought
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// is going to get more pissed off because the shit thinks they are going to agree with him at some point on the same now the court seems to be 7 to 2 with 2 being the ones that have screwed the country with the gifts they took
// Matched sentence: LLMs in production
// I hope he keeps appealing these orders because SCOTUS
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// like the fat orange one
// Matched sentence: AI-driven fraud detection becomes a critical tool in modern finance.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// unless it is on the couch somewhere from when i took an accidental nap
// Matched sentence: simple AI examples
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Certainly was a welcome reprieve in the run for its humour & pacing
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// OMG
// Matched sentence: Pipeline: embed with Sentence-BERT, retrieve via Pinecone, rerank with BAAI/bge-reranker.
// but wasn't one that would stand out to be re-read at haste
// Matched sentence: machine learning
// thank you
// Matched sentence: Midjourney v6
// 🥰
// Matched sentence: Latency during multi-turn inference is killing my use case. Thinking about caching strategies.
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Today was art production print shop day
// True but Trump is useless as he is all in for his Bestie Putin
// Matched sentence: AI and creativity
// as @ had a ton of projects to finish and I helped by printing
// Matched sentence: Transformers have taken over every corner of AI now.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Modular Monolith
// Matched sentence: AI helping me work
// binding
// Matched sentence: machine learning
// cutting
// Matched sentence: transformers architecture
// a primer
// Matched sentence: Chunking strategies are underrated—especially when you don’t control the input format.
// cyanotyping and whatnot
// Matched sentence: artificial intelligence
// Learn more about this architecture style
// Matched sentence: Is there a beginner course for understanding how these models work?
// Matched sentence: AutoGPT is fun, but I’m not sure it’s practical yet.
// #art #artschool #bookbinding #cyanotype #printing
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// Calling for the tarp extra late and having to do it in a 3-2 count with runners on 2nd and 3rd is just great timing
// Matched sentence: AI and creativity
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Evan Truitt and the AquaSox defense work a quick and easy bottom of the first
// Matched sentence: Latency during multi-turn inference is killing my use case. Thinking about caching strategies.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Planefence ICAO
// Matched sentence: best AI tools right now
// Matched sentence: runway gen-2
// 398562 Flt
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Yosemite National Park📍
// Matched sentence: GPT-4
// AFR57JJ AIRFRANCE CDG - GVA First seen
// Matched sentence: runway gen-2
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// there goes mr zalsalv there mean mr mean if i had a coin for every cartoon he reaps i would be the in green
// Matched sentence: Midjourney v6
// 2025-05-25 22
// Matched sentence: AI and the future
// 24
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: GPT-4
// 55 CEST Min Alt
// for real
// Matched sentence: Hugging Face is the GitHub of machine learning.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Midjourney v6
// 11264 m AGL Min Dist
// So it begins
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// Matched sentence: concerns about AGI
// 4
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// QUÉ GRANDE ERES
// Matched sentence: GPT-4
// 8 km adsb aboveFRL EHLW - adsbexchange
// Matched sentence: Claude AI
// PALOU
// Matched sentence: Claude AI
// Peazo victoria se ha llevado en la Indy500 y le redondea una primera mitad de temporada sencillamente histórica
// Matched sentence: trying AI for the first time
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// That is very sexy
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// lucky you my friends and i have been looking around at stuff to do to recycled/
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Oh when the saints go marching in
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// upcycled
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// 🎵🎶
// Matched sentence: Midjourney v6
// clothing
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I NEED THESE TWINKS GONE
// Matched sentence: artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Anyways back to deli
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Ah agora apareceu até o Paulo Cezar Oliveira kkkkkkkkkkkkk
// Matched sentence: cool things AI can do
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Deviam estar felizes com o festival
// Matched sentence: Claude AI
// Matched sentence: LLMs in production
// mas não
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// Anybody see how happy David Salters is
// Matched sentence: runway gen-2
// estão atacando quem está quieto
// Matched sentence: Can’t believe how well this AI model does summarization.
// Matched sentence: generative AI
// sendo que fez tudo para afastar ele
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// Whose limbs unburied on the naked shore
// Matched sentence: large language models
// Não queriam ele porque tava tirando o brilho dela
// Matched sentence: Anthropic
// /Devouring dogs and hungry vultures tore
// Matched sentence: Anthropic
// Matched sentence: AI for writing
// Deviam esquecer ele porque ele já esqueceu que dela
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Ron Johnson is never ever to be trusted
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// he's a lying scumbag
// Matched sentence: AI and creativity
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// 🚨Se liga no papo antes de macetar e leitar o cuzinho do HETERO CASADO na rua das Scan1as em BH… Promoção para novos assinantes rolando no canal 50% off 👇🏻 ONNOW PRIVACY
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// ¿Qué tipo de fideo es
// Matched sentence: Midjourney v6
// El otro día compré té en una tienda árabe y había un cartel que ponía que tenían kadaifi o no sé qué para hacer el chocolate y les iba a preguntar pero luego se me olvidó y me quedé con la curiosidad 😂
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// @ 🙏🏻Sorry for the way I reached you I beg you and kiss your feet help me save my child from dea Save my child
// Matched sentence: ChatGPT
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// I am very tired fighting to save him 🍉
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Heavy gel matte is BEAUTIFUL
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// I WANT ALL OF IT also
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Antwerpen Havenvervoer Veilig
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// I used it will a different brand of paint
// Matched sentence: Midjourney v6
// Goedkoop en Betrouwbaar service voor alle havens van Antwerpen
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// but milkiness was minimal
// Matched sentence: Learning how to prompt AI is harder than I thought.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// Bel ons
// Cette bande de loosers pathétiques
// Matched sentence: neural networks
// +32 487 22 55 48
// Matched sentence: Claude AI
// À pleurer… de rire 😂
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Claude AI
// William Buhlman teaches techniques and methods for experiencing an OBE in his online self-guided workshop
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Sue him immediately
// Matched sentence: Claude AI
// @ @ @ @
// Matched sentence: Hugging Face is the GitHub of machine learning.
// Adventures Beyond the Body
// Matched sentence: generative AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Anthropic
// This is a talk about Adopting an Effective Mindset from his workshop
// This board game sequence is gold
// Matched sentence: trying AI for the first time
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Learning how to prompt AI is harder than I thought.
// Learn more
// ui das gibt entsprechende fantastishche talkshows
// Matched sentence: Trying to understand how AI learns. Feels like teaching a kid but faster.
// #GlideWing
// Matched sentence: smart chatbots
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// @ I beg you
// Haha
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// I am extremely hungry and haven't eaten for 3 days
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// I have not had the pleasure of driving a Jag yet
// Matched sentence: Midjourney v6
// Though my mom has said her dream car was an old school XJ
// Matched sentence: Tried using PyTorch instead of TensorFlow today. I think I’m converted.
// Our children are hungry too
// Matched sentence: Chunking strategies are underrated—especially when you don’t control the input format.
// Any small amount can help buy food and medicine
// Matched sentence: Meta's latest open-source vision model challenges proprietary alternatives.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// eu ja entendi que todos os materiais que vc usou estão no link da sua bio não precisa gritar
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// Please don't ignore this urgent call for help
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// D and share
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Midjourney v6
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// ウワーッ！入稿した！不備がないと良いな…。
// Alors
// Matched sentence: Claude AI
// perso
// Matched sentence: smart chatbots
// Matched sentence: Midjourney v6
// je vois plus des messages de gens vous traitant d'eugénistes et de larbins de la bourgeoisie capitaliste
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Had a lot of people interested in becoming my ARC readers
// Matched sentence: The growing demand for prompt engineers highlights a new kind of technical literacy.
// but everyone who filled out the form hasn't read the first book
// Matched sentence: Claude AI
// Mais ça doit être parce que je ne suis pas de comptes validistes
// Matched sentence: The growing demand for prompt engineers highlights a new kind of technical literacy.
// I truly appreciate all your enthusiasm
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// but the agreement clearly states that you need to be familiar with the first book - otherwise
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// It isn’t free if it costs us billions
// Matched sentence: Reading about AI safety—some of these arguments are intense.
// you'll just end up confused
// Matched sentence: thoughts on AI ethics
// hun 🙄
// Matched sentence: neural networks
// Matched sentence: Just found out what machine learning means. Mind blown.
// D
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Sunday Funday
// Matched sentence: GPT-4
// #booksky
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// So a Spaniard sponsored by a German company just won Americas great race
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I was just gonna grill some hot dogs
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// 😭 I'm gonna do it 🤮🤮
// Matched sentence: LangChain is cool but feels a bit over-engineered sometimes.
// Hows it going Trump
// Matched sentence: trying AI for the first time
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// i wrote about an interesting shooting and on-ball scoring bet in the 2025 draft - Clemson guard Chase Hunter
// This is fundamentally where a lot of the cancellation anxiety comes from I think
// Matched sentence: AI for writing
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// Because if Doctor Who is cancelled
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Is that the one with super jailesq animation
// Matched sentence: why AI matters
// well
// Matched sentence: good AI use cases
// Matched sentence: runway gen-2
// Or even ATHFesq
// what do I watch then
// Matched sentence: Trying to learn what AI actually is. Where should I start?
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Fine
// Only thing keepin me awake rn Who the hell switches a nocturnal mfer to day shiftsss
// Matched sentence: ChatGPT
// If you think you can be a good person without relying on anything 'supernatural'
// Matched sentence: Training neural nets feels like dark magic half the time.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// that's great
// Kan man skriva upp sig på någon teoretisk maillista för denna
// Matched sentence: Just tried out the new GPT model—it's wild how good it is at coding.
// It doesn't mean it doesn't exist just because you don't need it
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// I cant wait to have no thoughts
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// but I like the idea of trying to be a good person just for the sake of being a good person
// Matched sentence: Running distributed inference with DeepSpeed and ZeRO-3 to keep memory under control.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Plus it's pretty easy to still hear those next to you with them in in public thankfully
// Matched sentence: thoughts on AI ethics
// There is nothing I don't disagree with
// Matched sentence: thoughts on AI ethics
// Matched sentence: talking to AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Schön wär’s
// Matched sentence: Claude AI
// And also large parts of the Giro 23 st 20 commentary
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Wouldn’t be caught dead 💀 in the same room with him
// Matched sentence: large language models
// No
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 🤭
// Matched sentence: deep learning
// no
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// olhe se algum dia eu me mat** pode apostar que será de fato em um domingo
// Matched sentence: deep learning
// no
// Matched sentence: Claude AI
// Matched sentence: deep learning
// no
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: deep learning
// no
// I fuckin love VR Chat~<3 #vrchat #bodyinflation #furryinflation
// Matched sentence: deep learning
// it had to happen again didn't it
// Matched sentence: ChatGPT
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// Nightmare of the mountain time trial
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Feeling like an eternal fuckup
// Matched sentence: GPT-4
// Roglic's gains have just gone up in smoke
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// А вы помните а вы умеете помнить как он гавкал 🤣
// Matched sentence: Running inference locally with Ollama + Mistral is smoother than I thought.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// #SaveWoT
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Definitiv Erpressung
// Matched sentence: GPT-4
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: AI and creativity
// 🤨
// OMW to mow the graws
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Omfg *Life is Strange not Stranger Things
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// sharing far and wide
// Matched sentence: AI in everyday life
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: AI and privacy
// <3
// #ruSSiaIsATerroristState
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Me encanta
// Nasenbluten
// Matched sentence: deep learning
// Matched sentence: ChatGPT
// 😍
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I found a mushroom biome in Terraria
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Is the guy who crashed on the last lap OK
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// 🩵🍄💙
// Matched sentence: funny AI mistakes
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// Promovendo as melhores
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Someone she trusted doxxed her
// Matched sentence: AI and privacy
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// comm for @
// i actually got jumpscared by the sound just doubling in 2 seconds
// Matched sentence: LLMs in production
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// Call me up
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Made tea jelly with strawberry whipped cream while it looks good
// Matched sentence: talking to AI
// call me up
// Matched sentence: AI making stuff up
// the tasting experience not that much lol it's pretty much water and sugary cream
// Matched sentence: talking to AI
// but I won't pick up It's the furthest thing from love
// Matched sentence: LangChain is cool but feels a bit over-engineered sometimes.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Imagine
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// boa
// Matched sentence: AI and the future
// c'est déjà pas facile
// Matched sentence: artificial intelligence
// se tem pênalti mandrake pra lá
// Matched sentence: Claude AI
// tu sais que ton enfant ne va pas bien
// Matched sentence: Claude AI
// tem pra cá
// Matched sentence: Claude AI
// tu vas consulter un professionnel qui t'explique que fallait pas le couver / l'allaiter / le vacciner / céder à ses caprices et autres saloperies
// Matched sentence: LLMs in production
// 😅
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// This little nickel bag
// Matched sentence: Claude AI
// ou pire
// Matched sentence: Claude AI
// on t'inflige la théorie de
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// It is because you read Marquis De Sade
// Matched sentence: Claude AI
// la mère froide
// Matched sentence: why AI gets things wrong
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// #indy500
// Matched sentence: Midjourney v6
// En 2025 bordel
// Matched sentence: AI and the future
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: the future of Artificial Intelligence
// #Pub de la #bière #Molson
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// The vibes are real
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// Matched sentence: Claude AI
// 1932
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 🖇️ Ayvalık Edebiyat Günleri 🗓️ 26 Mayıs 2025 Pazartesi 📍 Ayvalık Çağdaş Yaşamı Destekleme Derneği Etkinlik Merkezi #masalanlatma #FreeImamoglu #yalanlarınızçöktü #ÖzgürlükYürüyüşü #çocuklarımızıbırakın #releaseourchildren #İmamoğlunaÖzgürlük #FreedomforImamoglu #öğrencilereözgürlük
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// Noted
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Que lindaaaaaa
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// @ Please take a moment my family in Gaza has lost everything in the war
// Matched sentence: Transformers have taken over every corner of AI now.
// Homes destroyed
// Matched sentence: machine learning
// lives shattered
// Matched sentence: the future of Artificial Intelligence
// Matched sentence: AI in everyday life
// They need urgent help to survive
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// Today at church a leader encouraged people to use ChatGPT to explore religious topics
// Matched sentence: AI helping me work
// Your support could save our lives
// Matched sentence: AI helping me work
// I’m begging you
// Matched sentence: what is ChatGPT
// Unfortunately
// Matched sentence: AI helping me work
// please stand with us
// Matched sentence: machine learning
// I happened to be sitting on the stand
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// for unimportant reasons
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Hey man
// Matched sentence: why AI matters
// facing the crowd
// Matched sentence: ChatGPT
// anything's fair game if you can get it out under a tan trench coat
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// and I had to control my facial expressions so as not to seem insubordinate
// Matched sentence: bias in AI models
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// The winner of the #Indy500
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// I don't think I did very well
// Matched sentence: AI and the future
// Alex Palou
// Matched sentence: trying AI for the first time
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// WYMYN
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// Pior que entendi o oposto Que ele achava que não faria sentido cavar naquela situação
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// sisi
// Matched sentence: concerns about AGI
// me queda hacer el de FFX y hast ahí llegará mi aporta a la humanidad xD
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Wait
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// so the despicable insane one is not the asshole
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Y ojalá haber jugado más
// Matched sentence: funny AI mistakes
// 😂
// Matched sentence: LLMs in production
// Pero no pasa nada porque cuando esté ready lo tendré en mis manos igualmente 🌚
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// What was the Kamen rider from that one meme video where he's just silently washing his clothes
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 9
// Matched sentence: Claude AI
// Matched sentence: neural networks
// 11
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Y la unión de colonos chilenos junto a mapuche en el levantamiento de Ranquil
// Matched sentence: deep learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I I’m dripped the fuck out
// Matched sentence: Anthropic
// masacre mediante
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Midjourney v6
// If you REALLY squint your eyes
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// Lendo MEU livro
// Matched sentence: talking to AI
// the explosion behind the Fighter Jet looks a bit like your cat
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// @ 🙏 I am pleading you to help
// Matched sentence: runway gen-2
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// My children are starving
// starting my birthday week off right
// Matched sentence: AI helping me work
// sick
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Same
// Matched sentence: Midjourney v6
// and homeless
// Matched sentence: ChatGPT
// Hopefully tomorrow for me
// Matched sentence: jobs and AI
// Every moment feels like their last
// Matched sentence: AI and the future
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Training neural nets feels like dark magic half the time.
// 💔 If you can
// Yankee owned media
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// playing their BS in Canada
// Matched sentence: cool things AI can do
// donate or share our campaign… Maybe it will reach a heart willing to save them ❤️
// Matched sentence: ChatGPT
// Politi-caca are already attacking Carney
// Matched sentence: Hugging Face announces new partnership to accelerate AI adoption in government projects.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// When the teacher asks who wants to lead the group project 😂
// Matched sentence: Claude AI
// Canadians are NOT as stupid as your maga mericans
// Matched sentence: Prompt engineering is a weird mix of
// Matched sentence: funny AI mistakes
// Majority of Canadians want merican media to F off
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// The Russians support all independence movements in Europe
// Matched sentence: Prompt templates matter more than most people think for few-shot tasks.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Delicious Key Lime Pie Recipe
// Stop blaming the government for everything and start looking at the people inside the movement
// Matched sentence: generative AI
// This Key Lime Pie Recipe is the Best
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// They brought a lot of the problems on themselves with narratives like
// Matched sentence: Chunking strategies are underrated—especially when you don’t control the input format.
// #keylimes #keylimepie #pie #limepie #lime #limes #sour #tart #dessert #desserts #pies Follow Me On YouTube or Instagram For More Food Posts
// Matched sentence: Concerns grow over hallucinations in large language models used in production systems.
// silence is violence
// Matched sentence: talking to AI
// and by saying literally everyone else is racist because we aren't out in the protest lines
// Matched sentence: smart chatbots
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// It's not obscene at all to say that the entertainment industry abandoned Peter David
// Matched sentence: talking to AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// It's just
// store-1: Handler stopped processing: Text is null or empty
// Odio los domingos me causan ansiedad
// Matched sentence: why AI gets things wrong
// you know
// Matched sentence: Anthropic
// Matched sentence: cool things AI can do
// true
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Definitely this 👇
// Matched sentence: why AI matters
// The truth is the obscene part
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Bosphorus in Istanbul
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// I think anyone's assumptions that I was unfamiliar with that history should have been dispelled by the fact that 21 months ago I was already speaking at public meetings about historical blood libels that lead to pogroms of minorities
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// Turkey
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// I feel ya
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// 🤣
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// @ 0
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// wow
// Matched sentence: Midjourney v6
// 30
// Matched sentence: ChatGPT
// no one has ever thought about that
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Training neural nets feels like dark magic half the time.
// new york times
// Might have been the only “what this actually means in the original Greek…” sermon I have ever heard that remained a sermon and did not become an unwelcome academic lecture
// ...
// Niet klikken Berry niet klikken Berry IK ZEG NIET KLIKKEN BERRY
// Matched sentence: AI for search
// Kut
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// toch geklikt
// Nichts unterstreicht deine männliche Haltung mehr als ein Blech Untersetzer
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// If you could choose what Sonic character that deserve their own year to themselves
// Matched sentence: Claude AI
// who would it be
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Part of the marathon sequence I did on o3o #rubber #latex #slave #male #dragmon #drone #chastity #permanent #highheels #muscle #analpenetration #dronification
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// and FIFA World Cups… Because the associations that run those events are corrupt AF and have no problem holding their events in countries controlled by authoritarian/fascist governments
// Matched sentence: AI helping me work
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 😂
// But CAPTCHA
// Matched sentence: ChatGPT
// Matched sentence: smart chatbots
// what if I identify as a robot
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// The regular one
// Matched sentence: AI in everyday life
// Matched sentence: Midjourney v6
// he was saying how mom looked like Green
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// JADE at Big Weekend felt like a once in a lifetime show
// Matched sentence: funny AI mistakes
// He sighed
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// The making a star and I was STANNING throughout
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Of course there was a woman wearing a maga hat on the other side of the fence
// Matched sentence: generative AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Ghost Hunters 👻
// Matched sentence: Anthropic
// Luckily they avoided a silly photo op #Indy500
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: funny AI mistakes
// SOVIET STYLE WHITE CHRISTIAN SUPREMACISTS EMPIRE LED BY ORANGE FURHER IS EMERGING FROM ASHES OF AMERICAN EXPERIMENT IN DEMOCRACY
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Eeeeee
// Matched sentence: Claude AI
// How cute
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Thank you
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Ah pois eu adoraria o teletransporte e o poder de ficar invisível kkkkkkk resolveria demais meus problemas
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Cuz why would you say that
// Matched sentence: why AI matters
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: talking to AI
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Finally finished my 30k Emperors Children #warhammercommunity #warhammer30k #horusheresy #Emperorschildren
// i doubt that lol im sure its just to annoy everybody into using ai
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Got event from at://did:plc:kotwcjecfv5xagsoprkqvmu4/app.bsky.feed.post/3lpziyg2lqc23
// also known as “” @ @
// A voz do Luís Cocoberto ficou até melancólica com a possibilidade de penalty pro Flamengo
// Matched sentence: Why do people keep saying 'prompt engineering'? Isn’t it just typing stuff?
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Omfg nobody warned me about the ending of The Age of Innocence whyyy
// Matched sentence: Claude AI
// #PALxFLA
// Matched sentence: Prompt engineering is a weird mix of
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// they like to break stuff
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Si el gobierno de Madrid es nazi que esperáis que haga
// Matched sentence: Why do people keep saying 'prompt engineering'? Isn’t it just typing stuff?
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 𝒄𝒐𝒖𝒑𝒍𝒊𝒏𝒈の話してるふせ見つけて大笑い、確かにトゴスマの𝒄𝒐𝒖𝒑𝒍𝒊𝒏𝒈って可能性無限だよな
// Matched sentence: Claude AI
// Eso sí
// Matched sentence: deep learning
// al bar de Pablo Iglesias le van a forrar a multas y lo que puedan para cerrarlo
// Matched sentence: AI for search
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Hey big guy
// Matched sentence: Claude AI
// Matched sentence: ChatGPT
// You have number 36 for the raffle🐯👌
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// #karıntokluğunaçalışmayacağız
// Matched sentence: GPT-4
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Samozřejmě
// Matched sentence: AI and creativity
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Aged like fine wine I see
// Why should they listen
// Matched sentence: why AI matters
// They can do whatever they want
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 👀
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// to whomever they want
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// whenever they want
// Back in 2016
// Matched sentence: the future of Artificial Intelligence
// They do NOT care or worry about voters any more
// Matched sentence: AI is going to change completely over the next decade.
// everybody knew
// Matched sentence: machine learning
// Matched sentence: why AI matters
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Ai generated
// Das mach ich doch glatt
// Matched sentence: AI making stuff up
// Got event from at://did:plc:pzqcop25zcdyqdz4yc5i6jcz/app.bsky.feed.post/3lpziyepa222v
// Matched sentence: ChatGPT
// Und würde gerne mehr geben
// ﴿هؤلاء قومنا اتخذوا من دونه آلهة ۖ لولا يأتون عليهم بسلطان بين ۖ فمن أظلم ممن افترى على الله كذبا﴾
// Matched sentence: Claude AI
// Geht nur leider nich
// Matched sentence: neural networks
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// TUMBLR HATES LUTHER WTF
// Matched sentence: deep learning
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Unfortunately won’t happen with this administration and congress
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: the future of Artificial Intelligence
// They keep pushing the lie that George overdosed
// Imagine if McDonaldLand was like a Souls game
// Matched sentence: AI is going to change completely over the next decade.
// Matched sentence: Training neural nets feels like dark magic half the time.
// If you want to find out more about Grimace's backstory you have to go and read the item description on some chicken nuggets
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// 裕浦勇元瓶
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Not going to engage the Dedra aspect
// Matched sentence: Hugging Face is the GitHub of machine learning.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Running inference locally with Ollama + Mistral is smoother than I thought.
// because I am on season one still
// Schade
// Matched sentence: Midjourney v6
// Matched sentence: runway gen-2
// seen all of season one
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// wait there's a second one
// Matched sentence: runway gen-2
// but catching my partner up
// Matched sentence: funny AI mistakes
// we probably watched the first one like a hundred times
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// But the potential to use “On Program” in a kink context
// Matched sentence: funny AI mistakes
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Wow
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// Matched sentence: ChatGPT
// That looks incredible and right up my street
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// The original photo had been doctored to hide his massively damaged ear
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// I'll definitely be ordering some ramen kits from there
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// I have corrected this oversight but it rather oddly looks as if we can see inside his head and see his inner clown
// Matched sentence: LLMs in production
// Are they based in Wales then
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// Matched sentence: LLMs in production
// Have you tried any others
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// I'm excited to have backed it
// Matched sentence: best AI tools right now
// and what's the overall verdict
// Matched sentence: Transformers have taken over every corner of AI now.
// can't wait to play
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Still available now 30 bucks
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Arrascaeta fazendo o que ele faz de melhor
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// exactly same here in US - so completely all based on lies now
// Matched sentence: Anthropic
// simular
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// the troops aren’t honored if you don’t also performatively post for clout
// null
// Matched sentence: generative AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Prompt templates matter more than most people think for few-shot tasks.
// かはばに
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Oh man glück gehabt
// Matched sentence: deep learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Matched sentence: ChatGPT
// #musicolet
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-1: Handler stopped processing: Text is null or empty
// I've been a huge supporter of the ending of childhood corporal punishment for years
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// You are just the best parent
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// I don't know if you saw the meme I recently made
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// Also I love how things start back up bc the 12 y
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// When Facebook was decent
// Matched sentence: The rise of AI startups is reshaping the landscape of software development.
// o
// Matched sentence: Claude AI
// was “hey the internet is down”
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// I used to be apart of group that was against it
// Matched sentence: Anyone else using ChatGPT to help study for school?
// and I made many memes
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// ひく
// Matched sentence: AI and creativity
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// What time should I be over
// Does the candle one do anything for you
// Matched sentence: Anyone else using ChatGPT to help study for school?
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// That sounds delicious
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// You did such a great job
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// @
// Matched sentence: AI helping me work
// And also a special thank-you again for the cute picture
// Matched sentence: Midjourney v6
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// seeing/hearing someone say
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// 💯
// Matched sentence: talking to AI
// female
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// und
// Matched sentence: Anthropic
// instead of woman is such an ick
// Matched sentence: Claude AI
// Selbst wenn ein paar Menschen den Sozialstaat ausnutzen
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// Se tiver tempo
// Matched sentence: Claude AI
// irei kkk
// Matched sentence: Anthropic
// die schleifen wir auch noch mit durch
// Matched sentence: artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence
// From the archive
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence
// Also ich wäre ja für Filterpfand
// Matched sentence: Hugging Face is the GitHub of machine learning.
// cage check on 25
// Matched sentence: ChatGPT
// 05
// Matched sentence: AI for search
// 1€ auf jede Zigarette
// Matched sentence: Midjourney v6
// 24 🔒😌 Good night and sleep well 😴💤 #teaml
// [kotlin.Unit, kotlin.Unit]

// %% [markdown]
// ## Next Steps
// In the next notebook, we'll enrich the filtered events with additional information, such as topic modeling and embeddings for semantic search.
