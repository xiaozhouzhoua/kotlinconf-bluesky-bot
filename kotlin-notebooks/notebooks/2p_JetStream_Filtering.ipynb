// %% [markdown]
// # Filtering JetStream Events

// %% [markdown]
// In this notebook, we'll filter events from the Redis Stream that we created in the previous notebook. We'll use a combination of techniques to filter the events:
//
// 1. Deduplication using Redis Bloom Filter to avoid processing the same event multiple times
// 2. Content-based filtering using a machine learning model to identify software-related posts
// 3. Storing filtered events in Redis for further processing
//
// Redis Bloom Filter is a probabilistic data structure that allows us to check if an element is in a set. It's very memory efficient and has a constant time complexity for both insertion and lookup operations. The trade-off is that it can have false positives, but the probability of false positives can be controlled by the size of the filter.
//
// Machine learning models can be used to classify text into different categories. In this notebook, we'll use a pre-trained zero-shot classification model to classify posts as software-related or not.

// %% [markdown]
// ## Consuming from Redis Streams

// %% [markdown]
// ### Model Redis Streams Event
// In this section, we'll define a data class to represent the events stored in the Redis Stream. This model will be used to deserialize the events from the stream.

// %% [markdown]
// ### Creating a Redis Client
// Create a Jedis client to connect to Redis. This is a reusable client that can be used to interact with Redis Streams.

// %% [markdown]
// ### Creating a Consumer Group
// Create a consumer group to read from the Redis Stream. A consumer group allows multiple consumers to read from the same stream without duplicating the work. Each consumer in the group will receive a different subset of the messages.
//
// A consumer group can be created in Redis with the XGROUP CREATE command:
//
// `XGROUP CREATE streamName groupName id [MKSTREAM]`
//
// To create a consumer group in this notebook, we will encapsulate the command in a function. The function will take the stream name and the group name as parameters.

// %%
%use coroutines

// %%
import redis.clients.jedis.StreamEntryID
import dev.raphaeldelio.*

fun createConsumerGroup(streamName: String, consumerGroupName: String) {
    try {
        jedisPooled.xgroupCreate(streamName, consumerGroupName, StreamEntryID("0-0"), true)
    } catch (_: Exception) {
        println("Group already exists")
    }
}

// %%
createConsumerGroup("jetstream", "printer-example")

// %% [markdown]
// ### Reading from the Stream
// Create a reusable function to read from the stream. This function will read from the stream and return a list of entries. It uses the XREADGROUP command to read from the stream as part of a consumer group:
//
// `XREADGROUP GROUP groupName consumerName COUNT count BLOCK blockTime streamName id`
//
// The command will be encapsulated in a function that takes the stream name, consumer group name, consumer name, and count as parameters. The function will return a list of entries.

// %%
import redis.clients.jedis.params.XReadGroupParams
import redis.clients.jedis.resps.StreamEntry

fun readFromStream(
    streamName: String,
    consumerGroup: String,
    consumer: String,
    count: Int
): List<Map.Entry<String, List<StreamEntry>>> {
    return jedisPooled.xreadGroup(
        consumerGroup,
        consumer,
        XReadGroupParams().count(count),
        mapOf(
            streamName to StreamEntryID.XREADGROUP_UNDELIVERED_ENTRY
        )
    ) ?: emptyList()
}

// %% [markdown]
// ### Acknowledging Messages
// Create a function to acknowledge the message. This is important to let Redis know that the message has been processed successfully, so it won't be delivered to other consumers in the group.
//
// This is done by using the XACK command:
//
// `XACK streamName groupName id`
//
// The command will be encapsulated in a lambda function that takes the stream name, consumer group name, and entry as parameters. The function will acknowledge the message by calling the XACK command.

// %%
fun ackFunction(): (streamName: String, consumerGroup: String, entry: StreamEntry) -> Unit {
    return { streamName, consumerGroup, entry ->
        jedisPooled.xack(
            streamName,
            consumerGroup,
            entry.id
        )
    }
}

// %% [markdown]
// ### Consuming the Stream
// Create a reusable function to consume the stream.
//
// This function implements a pipeline pattern where each event is processed sequentially by a series of handlers. If any handler returns false, the processing stops for that event.
//
// After processing the event, the function acknowledges the message using the ack function.

// %%
import kotlinx.coroutines.*

fun consumeStream(
    streamName: String,
    consumerGroup: String,
    consumer: String,
    handlers: List<(Event) -> Pair<Boolean, String>>,
    ackFunction: ((String, String, StreamEntry) -> Unit),
    count: Int = 1,
    limit: Int = 5
) {
    var lastMessageTime = System.currentTimeMillis()
    var consumed = 0

    while (consumed < limit) {
        val entries = readFromStream(streamName, consumerGroup, consumer, count)
        val allEntries = entries.flatMap { it.value }
        allEntries.map { entry ->
            consumed++
            val event = Event.fromMap(entry)

            for (handler in handlers) {
                val (shouldContinue, message) = handler(event)
                ackFunction(streamName, consumerGroup, entry)

                if (!shouldContinue) {
                    println("$consumer: Handler stopped processing: $message")
                    break
                }
            }
        }

        if (allEntries.isEmpty()) {
            val now = System.currentTimeMillis()
            if (now - lastMessageTime >= 2_000) {
                println("$consumer: No new messages for 2 seconds. Stopping.")
                break
            }
        }
    }

}

// %% [markdown]
// To test the consumeStream function, we'll create a simple handler that prints the event's URI.

// %%
val printUri: (Event) -> Pair<Boolean, String> = {
    println("Got event from ${it.uri}")
    Pair(true, "OK")
}

// %%
runBlocking {
    consumeStream(
        streamName = "jetstream",
        consumerGroup = "printer-example",
        consumer ="printer-1",
        handlers = listOf(printUri),
        ackFunction = ackFunction(),
        count = 1,
        limit = 500
    )
}
// Out:
// Got event from at://did:plc:hrq7ms4rl5lrsw34lpzbvjlh/app.bsky.feed.post/3m5xusmcvi223
// Got event from at://did:plc:k3wimrg4push7traaxkhlqa7/app.bsky.feed.post/3m5xusmuc6f2w
// Got event from at://did:plc:ctswaa3akyjzkb3h4uh3yysj/app.bsky.feed.post/3m5xuskq4i22o
// Got event from at://did:plc:jdsvv4sulwe6noba5vzgbhpj/app.bsky.feed.post/3m5xusmjjfc2c
// Got event from at://did:plc:zqtvad2ytbmk3rkgfliwckkm/app.bsky.feed.post/3m5xuslzokk2m
// Got event from at://did:plc:mrozf7u6e7kjpo7itbrudpc6/app.bsky.feed.post/3m5xusn2k2o25
// Got event from at://did:plc:adalcqifqldb3ylnl23o4i42/app.bsky.feed.post/3m5xus3elpr2a
// Got event from at://did:plc:qbpqqtacmhetus5vuuusardx/app.bsky.feed.post/3m5xusn2fgk2x
// Got event from at://did:plc:exw564o7lorkfrdgfb6w7dr2/app.bsky.feed.post/3m5xuskssg22d
// Got event from at://did:plc:74lqbbm4mfh2z626f2wbv4ez/app.bsky.feed.post/3m5xusktppk2n
// Got event from at://did:plc:x3zwmocp6ul45xvqnviq5svw/app.bsky.feed.post/3m5xusmm4fk2a
// Got event from at://did:plc:3fjjthygxidt4qsu54salrm2/app.bsky.feed.post/3m5x25lluns2m
// Got event from at://did:plc:witgt5ucbyvgsumweetgv5fe/app.bsky.feed.post/3m5xusk5mok22
// Got event from at://did:plc:4g7sl7kmjlkquyi2hgnfgcsl/app.bsky.feed.post/3m5xusmtwfk2d
// Got event from at://did:plc:ue3yrdlzm6utmfdou54uwlxa/app.bsky.feed.post/3m5xut2jfgc2x
// Got event from at://did:plc:h2rie2dkjdeqg63f2unfwuby/app.bsky.feed.post/3m5xusxgyyc2x
// Got event from at://did:plc:oegdajffjifec3loq557pu4t/app.bsky.feed.post/3m5xut3f63s2z
// Got event from at://did:plc:baxkq7jq45xet6mysjzgmioc/app.bsky.feed.post/3m5xut36m522b
// Got event from at://did:plc:6kdptqv5yf64aowqvbwf7pfi/app.bsky.feed.post/3m5xut4dujc2m
// Got event from at://did:plc:f4aoikj3xtrw5l46bc3jeyx6/app.bsky.feed.post/3m5xut2fs6s2h
// Got event from at://did:plc:cb7z3ykxqporfdjmsxbbzp7p/app.bsky.feed.post/3m5xsqtfe322v
// Got event from at://did:plc:aj7l6nr2x44arw6xjkabz26a/app.bsky.feed.post/3m5xuwlbqjf22

// %% [markdown]
// ## Semantic Classifier
// In this section, we'll use a vector similarity search to filter posts based on their content.
// We'll use a embed a list of references and classify the posts based on their similarity to the references.
// If the post is similar to the references, it will be classified as artificial-intelligence-related.

// %% [markdown]
// ### Including Spring AI Redis Vector Store
// The Redis Vector Store is a Spring AI module that allows you to store and retrieve vectors in Redis. It uses the Redis Vector Search feature to perform similarity searches on the vectors.

// %%
@file:DependsOn("org.springframework.ai:spring-ai-redis-store:1.0.0")
@file:DependsOn("org.springframework.ai:spring-ai-transformers:1.0.0")

// %% [markdown]
// ### Initializing an embedding model
// The embedding model is used to convert text into vectors. The Redis Vector Store uses the embedding model to store and retrieve vectors in Redis.
//
// The Transformers Embedding Model provided by Spring AI uses all-minilm-l6-v2 model by default which has 384 dimensions.
//
// The model is loaded from the Hugging Face Hub and can be used to convert text into vectors.

// %%
import org.springframework.ai.transformers.TransformersEmbeddingModel

val embeddingModel = TransformersEmbeddingModel()
embeddingModel.setModelResource("https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/onnx/model.onnx?download=true")
embeddingModel.setTokenizerResource("https://huggingface.co/sentence-transformers/all-mpnet-base-v2/raw/main/tokenizer.json")
embeddingModel.afterPropertiesSet()

// %% [markdown]
// ### Creating the store (and the index in Redis)
// By creating an index in Redis, we can use the Redis Vector Search feature to perform similarity searches on the vectors.

// %%
import org.springframework.ai.vectorstore.redis.RedisVectorStore
import org.springframework.ai.vectorstore.redis.RedisVectorStore.MetadataField
import redis.clients.jedis.search.Schema.FieldType
import dev.raphaeldelio.jedisPooled

val redisVectorStore = RedisVectorStore.builder(jedisPooled, embeddingModel)
    .indexName("classifierIdx")
    .contentFieldName("text")
    .embeddingFieldName("textEmbedding")
    .prefix("classifier:")
    .initializeSchema(true)
    .vectorAlgorithm(RedisVectorStore.Algorithm.FLAT)
    .build()
redisVectorStore.afterPropertiesSet()

// %% [markdown]
// ### Storing the references as vectors
//
// The references are stored in Redis as vectors. The vectors are created using the embedding model and stored in the Redis Vector Store.

// %%
import kotlinx.serialization.json.Json
import org.springframework.ai.document.Document
import java.io.File
import java.util.UUID

val references = Json.decodeFromString<List<String>>(File("resources/filtering-examples.json").readText())

fun storeFilterDocumentsInRedis(references: List<String>) {
    val documents = references.map { text ->
        createFilterDocument(text)
    }

    redisVectorStore.add(documents)
}

fun createFilterDocument(text: String): Document {
    return Document(
        UUID.randomUUID().toString(),
        text,
        mapOf(
            "text" to text,
        )
    )
}

storeFilterDocumentsInRedis(references)

// %% [markdown]
// ### Creating a Classification Function
// Now we'll create a function to classify text using the model.
//
// The function takes a text as input and returns a classification output. The classification output contains the probabilities for each candidate label.

// %%
import ai.djl.modality.nlp.translator.ZeroShotClassificationOutput
import org.springframework.ai.vectorstore.SearchRequest

fun classify(post: String): List<Double> {
    //val cleanedPost = removeUrls(post)
    return breakSentenceIntoClauses(post).map { clause ->
        println(clause)
        (redisVectorStore.similaritySearch(
            SearchRequest.builder()
                .topK(1)
                .query(clause)
                .build()
        )?.map {
            println("Matched sentence: ${it.text}")
            it.score ?: 0.0
        } ?: emptyList())
    }.flatten()
}

// %%
classify("Redis is a great tool for building applied AI systems because it's a Vector Database")
// Out:
// Redis is a great tool for building applied AI systems because it's a Vector Database
// Matched sentence: best AI tools right now
// [0.8059492111206055]

// %%
classify("I'm here at KotlinConf, I can't stand people talking about AI anymore.")
// Out:
// I'm here at KotlinConf
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// I can't stand people talking about AI anymore
// Matched sentence: why AI matters
// [0.6877487897872925, 0.8056651949882507]

// %%
classify("Redis is a great tool for building distributed systems")
// Out:
// Redis is a great tool for building distributed systems
// Matched sentence: RAG architectures are emerging as the go-to solution for enterprise search systems.
// [0.6799676418304443]

// %%
classify("Santos is the best city of Brazil.")
// Out:
// Santos is the best city of Brazil
// Matched sentence: Claude AI
// [0.575647234916687]

// %% [markdown]
// Optimizer for finding the best threshold for the classification function: https://github.com/redis-developer/redis-ai-resources/blob/main/python-recipes/semantic-router/01_routing_optimization.ipynb

// %% [markdown]
// ### Creating a Filter Handler
// Now we'll create a handler that filters events based on their content.
//
// The handler uses the classification function to determine if a post is software-related.
//
// If the post is not software-related, the handler returns false, which stops the processing of the event.

// %%
fun breakSentenceIntoClauses(sentence: String): List<String> {
    return sentence.split(Regex("""[!?,.:;]+"""))
        .filter { it.isNotBlank() }.map { it.trim() }
}

fun removeUrls(text: String): String {
    return text.replace(Regex("""(?:https?:\/\/)?(?:www\.)?[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(\/\S*)?"""), "")
        .replace(Regex("""@\w+"""), "")
        .replace(Regex("""\s+"""), " ")
        .trim()
}

// %%
val filter: (Event) -> Pair<Boolean, String> = { event ->
    if (event.text.isNotBlank() && event.langs.contains("en") && event.operation != "delete") {
        val classification = classify(event.text)
        if (classification.any { it > 0.75 }) {
            Pair(true, "OK")
        } else {
            Pair(false, "Not a post related to artificial intelligence: Score: ${classification} \n${event.text}\n")
        }
    } else {
        Pair(false, "Text is null or empty")
    }
}

// %% [markdown]
// ## Storing Filtered Events
// In this section, we'll store the filtered events in Redis for further processing.

// %% [markdown]
// ### Storing Events in Redis
// Now we'll create a handler that stores events in Redis. The handler stores the event as a hash in Redis, with the key being the event's URI.

// %%
val storeEvent: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.hset("post:" + event.uri.replace("at://did:plc:", ""), event.toMap())
    Pair(true, "OK")
}

// %% [markdown]
// ### Adding Filtered Events to a New Stream
// Finally, we'll create a handler that adds filtered events to a new stream. This allows other consumers to process only the filtered events, rather than having to filter the events themselves.

// %%
import redis.clients.jedis.params.XAddParams

val addFilteredEventToStream: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.xadd(
        "filtered-events",
        XAddParams.xAddParams().id(StreamEntryID.NEW_ENTRY),
        event.toMap()
    )
    Pair(true, "OK")
}

// %%
createConsumerGroup("jetstream", "store-example")

// %% [markdown]
// ## Putting It All Together
// Now we'll put all the pieces together to create a complete pipeline for filtering events from the Redis Stream.
//
// In this example we create two consumers that will process the same stream.
// - By doing that, we can scale the processing of the events by adding more consumers to the group.
// - Redis will make sure that each consumer will receive different messages.

// %%
runBlocking {
        listOf(
            async(Dispatchers.IO) {
                consumeStream(
                    streamName = "jetstream",
                    consumerGroup = "store-example",
                    consumer = "store-1",
                    handlers = listOf(
                        filter,
                        printUri,
                        storeEvent,
                        addFilteredEventToStream
                    ),
                    ackFunction = ackFunction(),
                    count = 1,
                    limit = 400
                )
            },
            async(Dispatchers.IO) {
                consumeStream(
                    streamName = "jetstream",
                    consumerGroup = "store-example",
                    consumer = "store-2", // Different consumer
                    handlers = listOf(
                        filter,
                        printUri,
                        storeEvent,
                        addFilteredEventToStream
                    ),
                    ackFunction = ackFunction(),
                    count = 1,
                    limit = 400
                )
            }
        ).awaitAll()
}
// Out:
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// 1993 i convinced my then GF that spending £100 on doubling my ram to 8MB was enough to last me a lifetime 😂
//
// Sarah
// minha bateria vai acabar adeus
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6494318246841431]
// minha bateria vai acabar adeus
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// I'm sorry
// store-2: Handler stopped processing: Text is null or empty
// hey can I not see full on uncensored porn on here🥺🥺🥺🥺🥺🥺🥺🥺
// Matched sentence: ChatGPT
// at the time
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// Matched sentence: Anthropic
// I believe this to be true
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5999985933303833]
// hey can I not see full on uncensored porn on here🥺🥺🥺🥺🥺🥺🥺🥺
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6017017960548401, 0.5949086546897888, 0.5802270174026489, 0.6323467493057251]
// 1993 i convinced my then GF that spending £100 on doubling my ram to 8MB was enough to last me a lifetime 😂
//
// Sarah, I'm sorry, at the time, I believe this to be true
//
// Easy to overdo the historical comparison
// store-2: Handler stopped processing: Text is null or empty
// Profile_Pic_01 and what was initially face practice of Aiden
// I really love his coat design
// Im having alot of fun putting it all together
// #WatchdogsRO2 #Watchdogs #AidenPearce
// Matched sentence: AI vs humans
// but pope as a national figure & counterweight to political regime recalls JP II and Poland under communism
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6859610080718994]
// Profile_Pic_01 and what was initially face practice of Aiden
// I really love his coat design
// Im having alot of fun putting it all together
// #WatchdogsRO2 #Watchdogs #AidenPearce
//
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6122353076934814, 0.5680890679359436]
// Easy to overdo the historical comparison, but pope as a national figure & counterweight to political regime recalls JP II and Poland under communism.
//
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Ese fue mi Spiderman por muchos años
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// So impressed with Matthew Prince
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5950973033905029]
// Ese fue mi Spiderman por muchos años.
//
// Matched sentence: The latest paper on transformer models just dropped—crazy improvements.
// Cloudflare CEO
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Frightened to say it
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// Read his response to the question of how they could get a post-mortem out so quickly
// Matched sentence: talking to AI
// but let's hope he stays fit for the tournament
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6027418971061707, 0.5761377215385437]
// Frightened to say it, but let's hope he stays fit for the tournament.
//
// 샘플 잘 나옴
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// Leadership++ news
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// ycombinator
// Matched sentence: ChatGPT
// ☺️🫶
// Matched sentence: Just tried out the new GPT model—it's wild how good it is at coding.
// com/item
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5855758190155029, 0.6155469417572021]
// 샘플 잘 나옴,,, ☺️🫶
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// ▶️ #NowPlaying on Hot 21 Radio
// Matched sentence: runway gen-2
// id=4597
// Matched sentence: ChatGPT
// Folded by Kehlani
//
// 🔥 Tune in now
// Matched sentence: ChatGPT
// #cloudflare
// Matched sentence: Midjourney v6
// https
// Matched sentence: The rise of AI startups is reshaping the landscape of software development.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6060398817062378, 0.6705983281135559, 0.6145385503768921, 0.6407998204231262, 0.6410702466964722, 0.5935673713684082, 0.6088055968284607, 0.6208702325820923]
// So impressed with Matthew Prince, Cloudflare CEO. Read his response to the question of how they could get a post-mortem out so quickly. Leadership++ news.ycombinator.com/item?id=4597... #cloudflare
//
// Matched sentence: AI and privacy
// //www
// store-2: Handler stopped processing: Text is null or empty
// #gozsFanart #fanart
// らくがき海財
// Matched sentence: ChatGPT
// hot21radio
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// 上目遣い
// Matched sentence: ChatGPT
// com
//
// #Hot21Radio #HipHop #RnB #WeTheBestHipHopandRnB
//
// Upcoming
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6064220070838928, 0.6194626688957214]
// #gozsFanart #fanart
// らくがき海財(上目遣い)
//
// From my YouTube Channel
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// “I don’t know if this translates into…” ow
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// Belly Gang Kushington - Friend do
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5923984050750732, 0.6171779036521912, 0.6176552772521973, 0.6029556393623352, 0.6226344108581543, 0.6063632965087891, 0.6250055432319641]
// ▶️ #NowPlaying on Hot 21 Radio:
// Folded by Kehlani
//
// 🔥 Tune in now:
// https://www.hot21radio.com
//
// #Hot21Radio #HipHop #RnB #WeTheBestHipHopandRnB
//
// Upcoming: Belly Gang Kushington - Friend do
//
// Another excellent article from Rafael Baer
// Matched sentence: talking to AI
// ly/Hsza50MuXNn
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6570284962654114]
// Another excellent article from Rafael Baer
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Arigatou Misako
// Matched sentence: deep learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6151241064071655, 0.6086339950561523, 0.6141728162765503]
// From my YouTube Channel: “I don’t know if this translates into…” ow.ly/Hsza50MuXNn
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// BEE
//
// #Videogames #Skychildrenofthelight #SkyCOTL #Thatskygame
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6912398338317871]
// Arigatou Misako :)
//
// The case for throwing Glasman out of the Labour party is unanswerable
// Matched sentence: fun AI projects
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6381028890609741]
// BEE
//
// #Videogames #Skychildrenofthelight #SkyCOTL #Thatskygame
//
// store-2: Handler stopped processing: Text is null or empty
// I also get uptight when someone comes to tell me about this never-before-seen
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// Hopefully
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// new idea
// Matched sentence: the future of Artificial Intelligence
// it will happen when Starmer goes
// Matched sentence: artificial intelligence
// that will revolutionize all genres
// Matched sentence: AI is going to change completely over the next decade.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5718679428100586, 0.6274824142456055, 0.6091084480285645]
// The case for throwing Glasman out of the Labour party is unanswerable. Hopefully, it will happen when Starmer goes.
//
// same
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// No
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6106341481208801]
// same
//
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Anyone else using ChatGPT to help study for school?
// It's all been done
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// The apparent wall between your body and the world is more like a picket fence
// Matched sentence: Anthropic
// and it's probably been done better
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// And between your mind and the world
// Matched sentence: I didn’t think AI could do creative stuff, but I was wrong.
// The artistry is in writing it your way with your words and your work put into it
// Matched sentence: AI and creativity
// it's like a line painted on the sidewalk
// Matched sentence: AI and creativity
// And that's being a writer
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6099931597709656, 0.636654257774353, 0.6106982231140137]
// The apparent wall between your body and the world is more like a picket fence. And between your mind and the world, it's like a line painted on the sidewalk.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: AI for writing
// That's nice
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6139737963676453, 0.6339377164840698, 0.7208337187767029, 0.5870121717453003, 0.6011080741882324, 0.6553595066070557, 0.7270371317863464, 0.7250124216079712]
// I also get uptight when someone comes to tell me about this never-before-seen "new idea" that will revolutionize all genres.
//
// No. It's all been done...and it's probably been done better. The artistry is in writing it your way with your words and your work put into it. And that's being a writer.
//
// Écoute tes parents ne t’ont jamais offert une doudoune qui te fait ressembler à Marine Le Pen au ski donc c’est déjà ça de pris
// Matched sentence: Tried using PyTorch instead of TensorFlow today. I think I’m converted.
// Um
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// I-I'm really glad about that actually
// Matched sentence: Claude AI
// Oui j’ai échangé la doudoune Némésis contre un perfecto à clous
// Matched sentence: The latest paper on transformer models just dropped—crazy improvements.
// that you're… that you like listening
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6033774018287659, 0.6341461539268494]
// Écoute tes parents ne t’ont jamais offert une doudoune qui te fait ressembler à Marine Le Pen au ski donc c’est déjà ça de pris. Oui j’ai échangé la doudoune Némésis contre un perfecto à clous.
//
// Matched sentence: talking to AI
// I mean
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Happy Wednesday bud
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// 「* He really hoped that none of this made her uncomfortable
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// ☺️
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5771216154098511, 0.6155469417572021]
// Happy Wednesday bud! ☺️
//
// It's like Johnson is the guy in the cuck chair eagerly watching as Trump fucks America
// Matched sentence: how to prompt AI
// He wouldn't be able to tell right now
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// and Thune is in a gimp suit at his feet
// Matched sentence: talking to AI
// 」
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6137655973434448, 0.6155571937561035, 0.6074552536010742, 0.6481201648712158, 0.5709279775619507, 0.602749228477478, 0.5967100858688354, 0.6433241367340088]
// That's nice. Um, I-I'm really glad about that actually, that you're… that you like listening, I mean.
//
// 「* He really hoped that none of this made her uncomfortable. He wouldn't be able to tell right now.」
//
// store-1: Handler stopped processing: Text is null or empty
// gefahr a10 südlicher berliner ring
// Matched sentence: generating images with AI
// I bet the big guy from Texas would absolutely love that imagery
// Matched sentence: runway gen-2
// dreieck potsdam richtung schönefelder kreuz zwischen dreieck potsdam und ferch|gefahr durch gegenstände auf dem rechten fahrstreifen ein spanngurt
// Matched sentence: Embedding chunk size affects retrieval quality more than I expected.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.554336428642273, 0.5992300510406494, 0.5954782962799072]
// It's like Johnson is the guy in the cuck chair eagerly watching as Trump fucks America, and Thune is in a gimp suit at his feet.
//
// I bet the big guy from Texas would absolutely love that imagery.
//
// again
// Matched sentence: Anthropic
// not affiliated
// bonus
// Matched sentence: runway gen-2
// bitte vorsichtig fahren
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// FURRY VERSION AND ALSO LOOK AT THIS CUTE TAIL MY HEART I CANT
// Matched sentence: ChatGPT
// langsam fahren
// #Berlin #Verkehr #Baustelle #Sperrung #Störung #Straße
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6062226891517639, 0.5738264322280884, 0.6282256841659546]
// again, not affiliated
// bonus: FURRY VERSION AND ALSO LOOK AT THIS CUTE TAIL MY HEART I CANT
//
// fuck u liking purple is liky 50% of my personality
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6021548509597778, 0.5798156261444092, 0.6078684329986572, 0.5864973068237305]
// gefahr a10 südlicher berliner ring, dreieck potsdam richtung schönefelder kreuz zwischen dreieck potsdam und ferch|gefahr durch gegenstände auf dem rechten fahrstreifen ein spanngurt , bitte vorsichtig fahren, langsam fahren
// #Berlin #Verkehr #Baustelle #Sperrung #Störung #Straße
//
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Creative art
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.57354336977005]
// fuck u liking purple is liky 50% of my personality
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Paddy - Waitakere
// Matched sentence: AI and creativity
// Got event from at://did:plc:3kjkefkbscxkap3kgxvxnjvs/app.bsky.feed.post/3m5xuses6e22h
// store-1: Handler stopped processing: Text is null or empty
// *offers a hug*
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6134488582611084]
// Paddy - Waitakere
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// This is what was done in Russia during the collapse of the USSR
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6705028414726257]
// *offers a hug*
//
// store-1: Handler stopped processing: Text is null or empty
// Have you watched this yet
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5933579206466675]
// This is what was done in Russia during the collapse of the USSR.
//
// Matched sentence: Can’t believe how well this AI model does summarization.
// Thank you for answering
// The Cannonball Run with Robert Baldinger
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// I know that you are specialized in Franco-German defense matters
// Matched sentence: runway gen-2
// Great to see some friends in the riding mix
// Matched sentence: Claude AI
// and followed you here from twitter so reading you for years now
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// www
// Matched sentence: Anthropic
// youtube
// Matched sentence: large language models
// but I hoped that you may have more information in this context
// Matched sentence: neural networks
// com/watch
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// I have an impression Spain is largely absent from European military discussion
// Matched sentence: ChatGPT
// v=9glA
// Matched sentence: Transformers have taken over every corner of AI now.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.562065601348877, 0.6447568535804749, 0.6072769165039062, 0.6170745491981506, 0.5667144060134888]
// Thank you for answering!
//
// I know that you are specialized in Franco-German defense matters (and followed you here from twitter so reading you for years now), but I hoped that you may have more information in this context. I have an impression Spain is largely absent from European military discussion
//
// Matched sentence: GPT-4
// #motosky #motorcycles
// ebay
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// us/m/h0ZB5K
//
// My art store
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.600045919418335, 0.6194630861282349, 0.6135544776916504, 0.6474792957305908, 0.6333208084106445, 0.6265653371810913, 0.6049214601516724, 0.6185558438301086]
// Have you watched this yet? The Cannonball Run with Robert Baldinger. Great to see some friends in the riding mix!
//
// www.youtube.com/watch?v=9glA...
//
// #motosky #motorcycles
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Probably the third thing
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// check out the range and make offers
// All delivered worldwide safe
//
// Art is life
// Matched sentence: Anthropic
// The sex hormones do more than just make gender trouble
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// this is my craft
//
// #art #handmade #oc #ebay #forsale #fuckai #starvingartist #inks #painting #popart #folkart #comicart #darkart #design #uk #white
// Matched sentence: Prompt engineering is a weird mix of
// sadly
// Matched sentence: funny AI mistakes
// You just got stuck on the wrong planet or something
// Matched sentence: why AI gets things wrong
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6009911298751831, 0.5906535387039185, 0.5983867049217224, 0.620159387588501]
// Probably the third thing. The sex hormones do more than just make gender trouble, sadly. You just got stuck on the wrong planet or something.
//
// 17
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5778900384902954, 0.6108334064483643, 0.6147540807723999, 0.6578947901725769]
// ebay.us/m/h0ZB5K
//
// My art store, check out the range and make offers
// All delivered worldwide safe
//
// Art is life , this is my craft
//
// #art #handmade #oc #ebay #forsale #fuckai #starvingartist #inks #painting #popart #folkart #comicart #darkart #design #uk #white
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Yes they did
// Matched sentence: ChatGPT
// 51
// Matched sentence: The latest paper on transformer models just dropped—crazy improvements.
// thinking it would be more acceptable
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// J1 HITS - Now Playing
// Matched sentence: runway gen-2
// B'z - Illumination
// Matched sentence: Why do people keep saying 'prompt engineering'? Isn’t it just typing stuff?
// The bafflement on Mahmood’s face when Jeremy Corbyn’s brilliant speech was coming to an end and he was looking directly at her
// Matched sentence: runway gen-2
// イルミネーション
// Matched sentence: Hugging Face announces new partnership to accelerate AI adoption in government projects.
// No shame
// Matched sentence: ChatGPT
// -
// Matched sentence: ChatGPT
// just confusion
// Matched sentence: artificial intelligence
// 120 listeners
// Matched sentence: Trying to understand the difference between ChatGPT and Google. It’s not clear yet.
// They must allow anyone without an iota of intelligence to study Law
// Matched sentence: Running distributed inference with DeepSpeed and ZeRO-3 to keep memory under control.
// listen at j1fm
// Matched sentence: ChatGPT
// tokyo
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// I’m ok
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5986599922180176, 0.5993045568466187, 0.6291162967681885, 0.5743961930274963, 0.6155469417572021, 0.6302886009216309, 0.6225752234458923, 0.5989471673965454, 0.6067063212394714]
// [17:51] J1 HITS - Now Playing: B'z - Illumination (イルミネーション) - (120 listeners) listen at j1fm.tokyo
//
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// hubby isn’t
// Pero como va a ser lo de la izquierda
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5723109841346741, 0.6089237928390503, 0.6181986927986145, 0.6026542782783508, 0.6270378828048706, 0.6648380160331726, 0.5940163135528564, 0.5901063680648804]
// Yes they did, thinking it would be more acceptable!  The bafflement on Mahmood’s face when Jeremy Corbyn’s brilliant speech was coming to an end and he was looking directly at her.  No shame, just confusion.  They must allow anyone without an iota of intelligence to study Law.  I’m ok, hubby isn’t.
//
// Matched sentence: Claude AI
// Isle of DOGS
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Meanwhile the Public are Reminded #SaudiArabia
// #Funded the 9/11/2001 #TerroristAttacks on the #WorldTradeCenter #TwinTowers
// And #DonaldTrump thinks it is Okay to do Business with #SaudiArabia
// Matched sentence: Midjourney v6
// y no lo de la derecha
// Matched sentence: Claude AI
// estamos locos O QUE PASA AQUI
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5756743550300598]
// Meanwhile the Public are Reminded #SaudiArabia
// #Funded the 9/11/2001 #TerroristAttacks on the #WorldTradeCenter #TwinTowers
// And #DonaldTrump thinks it is Okay to do Business with #SaudiArabia
//
// Group sex is so fucking hot its insane
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6021857857704163, 0.6538480520248413, 0.5854384303092957, 0.5717244744300842]
// Pero como va a ser lo de la izquierda "Isle of DOGS" y no lo de la derecha, estamos locos O QUE PASA AQUI??
//
// store-1: Handler stopped processing: Text is null or empty
// Thank you
// Matched sentence: Midjourney v6
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6142258048057556]
// Thank you!
//
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5846186876296997]
// Group sex is so fucking hot its insane
//
// Or the film that covers the face of a new watch
// store-1: Handler stopped processing: Text is null or empty
// ADHD meds
// Matched sentence: Hugging Face is the GitHub of machine learning.
// Matched sentence: AI tools I like
// exist
// Me
// and how much clearer the time looks when you get the damn film off
// Matched sentence: Anthropic
// ‘I’d totally get addicted to you… if I remembered you existed before 3pm
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6166802048683167, 0.6264020204544067]
// Or the film that covers the face of a new watch, and how much clearer the time looks when you get the damn film off.
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// hehe thank youu 🫶🏻🩷
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// Matched sentence: Anyone else using ChatGPT to help study for school?
// ’
// #ADHDLife #NeurospicyHumor #ADHDCommunity
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6006181240081787]
// hehe thank youu 🫶🏻🩷
//
// fellow musicians
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// send the oddballs to me
// Matched sentence: Concerns grow over hallucinations in large language models used in production systems.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5858906507492065, 0.6243739128112793, 0.6054260730743408, 0.627608060836792]
// ADHD meds: exist
// Me: ‘I’d totally get addicted to you… if I remembered you existed before 3pm.’
// #ADHDLife #NeurospicyHumor #ADHDCommunity
//
// oh i got so caught up in writing knight yuri i forgot i had library books
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// what you have planned for innocence is so fucked that doctor dude wants in
// Matched sentence: AI for writing
// my bad
// Matched sentence: thoughts on AI ethics
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6386061906814575, 0.6277408003807068, 0.5989125967025757]
// fellow musicians, send the oddballs to me. what you have planned for innocence is so fucked that doctor dude wants in.
//
// store-2: Handler stopped processing: Text is null or empty
// wow
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6196804642677307, 0.5737025141716003]
// oh i got so caught up in writing knight yuri i forgot i had library books. my bad.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Just found out what machine learning means. Mind blown.
// not cool
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Big news for Dundalk
// Matched sentence: cool things AI can do
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6004350185394287, 0.5926581025123596]
// wow! not cool!
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// and Ireland more generally
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// www
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// Seems like this is might be the first formal NI/ROI higher ed direct partnership
// Matched sentence: Anthropic
// msn
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// Also we’ll have another combination of the letters U
// Matched sentence: ChatGPT
// com/en-us/news/w
// Matched sentence: the future of Artificial Intelligence
// C
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6474792957305908, 0.662365198135376, 0.6177011132240295]
// www.msn.com/en-us/news/w...
//
// Matched sentence: artificial intelligence
// and D in Ireland…
//
// UCD
// DCU
// DUC
// It's my game of the year too
// Matched sentence: Midjourney v6
// and it does not have a chance against these juggernauts of 2025
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5766927003860474, 0.5465704202651978, 0.6751686334609985, 0.6052471995353699, 0.6220762729644775, 0.587067723274231]
// Big news for Dundalk, and Ireland more generally. Seems like this is might be the first formal NI/ROI higher ed direct partnership.
//
// Also we’ll have another combination of the letters U, C, and D in Ireland…
//
// UCD
// DCU
// DUC
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// #ラブリーポップХワンダーランドの画像を貼って
// #AIイラスト
// Matched sentence: AI is going to change completely over the next decade.
// At least it'll expose more people to this fantastic game
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6560497283935547, 0.6197224855422974, 0.6033276915550232]
// It's my game of the year too, and it does not have a chance against these juggernauts of 2025. At least it'll expose more people to this fantastic game.
//
// Matched sentence: AI and the future
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5831081867218018]
// #ラブリーポップХワンダーランドの画像を貼って
// #AIイラスト
//
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// No need to apologize
// No point as the big manufacturing companies will just rebrand them as something else
// Matched sentence: ChatGPT
// dude 🫶
// Matched sentence: The growing demand for prompt engineers highlights a new kind of technical literacy.
// To the best of my knowledge no wet wipe is free from plastic so should not be put down the toilet
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5878979563713074, 0.6249163746833801]
// No need to apologize, dude 🫶
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// When all the evidence is released it will be interesting to see which high profile people and billionaires get out of the country
// Matched sentence: Prompt engineering is a weird mix of
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6402170658111572, 0.5558019280433655]
// No point as the big manufacturing companies will just rebrand them as something else.
//
// To the best of my knowledge no wet wipe is free from plastic so should not be put down the toilet.
//
// store-1: Handler stopped processing: Text is null or empty
// It's the manner and tone
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6018133163452148]
// When all the evidence is released it will be interesting to see which high profile people and billionaires get out of the country.
//
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Trying to understand how AI learns. Feels like teaching a kid but faster.
// People ticked off the Tories when they did it
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// We need to demand the see the un-edited videos from the multiple cameras at each of Epstein’s properties
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// So why is it ok for Labour
// Matched sentence: Meta's latest open-source vision model challenges proprietary alternatives.
// if they haven’t been ‘lost’
// Matched sentence: LLMs in production
// And please don't say
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// edited
// Matched sentence: Anthropic
// because it's Labour
// Matched sentence: artificial intelligence
// destroyed
// Matched sentence: Why do people keep saying 'prompt engineering'? Isn’t it just typing stuff?
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6334154009819031, 0.5756937265396118, 0.5906341075897217, 0.6021762490272522, 0.5912211537361145]
// It's the manner and tone.
//
// People ticked off the Tories when they did it. So why is it ok for Labour?
//
// (And please don't say "because it's Labour"!)
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Anthropic
// She should talk less
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5997902154922485, 0.5832962989807129, 0.5903912782669067, 0.6332669258117676]
// We need to demand the see the un-edited videos from the multiple cameras at each of Epstein’s properties (if they haven’t been ‘lost’, edited, destroyed.
//
// The GrUSP team has just published my talk “Custom PHPStan Rules
// Matched sentence: smart chatbots
// make fewer empty promises and concentrate on actually achieving something
// Matched sentence: Just tried out the new GPT model—it's wild how good it is at coding.
// Automate Standards and Save Time” from #phpday
//
// Custom PHPStan rules amplify the benefits of PHPStan and they are not as difficult as you might think to write
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// Lucky to still be in a job after the disastrous year she's had
// Matched sentence: jobs and AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6412633657455444, 0.6299467086791992, 0.6222173571586609]
// She should talk less, make fewer empty promises and concentrate on actually achieving something.  Lucky to still be in a job after the disastrous year she's had
//
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// I created 3 in this talk youtu
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Experimented with some generative AI using diffusion models today.
// be/1tOSnuxCcRY
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Nothing will ever convince me his appointment wasn't an act of internal sabotage
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6598423719406128, 0.615563154220581, 0.6744849681854248, 0.5968679189682007]
// The GrUSP team has just published my talk “Custom PHPStan Rules: Automate Standards and Save Time” from #phpday
//
// Custom PHPStan rules amplify the benefits of PHPStan and they are not as difficult as you might think to write. I created 3 in this talk youtu.be/1tOSnuxCcRY
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6110267639160156]
// Nothing will ever convince me his appointment wasn't an act of internal sabotage.
//
// I prefer to run HA in a virtual machine
// #goldenhourglow  #sunsetinspiration #iviira9 #coastalbeauty #calmingwaves #outdoorphotography #skylineart #eveningmagic #naturalbeauty
//
// #naturephotography #visualharmony
//
// #peacefulescapes #sunsetsymphony
//
// #explorethehorizon #breathtakingviews
// Matched sentence: Tried quantizing a model to run inference on CPU—speed gains are solid.
// I use XCP-NG and Xen Orchestra
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// but Proxmox is popular
// Matched sentence: Open-source alternatives to ChatGPT gain traction among developers and researchers.
// and ensuring the Zigbee controller is mounted over the network instead of USB
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6179929971694946]
//  #goldenhourglow  #sunsetinspiration #iviira9 #coastalbeauty #calmingwaves #outdoorphotography #skylineart #eveningmagic #naturalbeauty
//
// #naturephotography #visualharmony
//
// #peacefulescapes #sunsetsymphony
//
// #explorethehorizon #breathtakingviews
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Ein bisschen Küchenrolle / Klopapier hätte da Wunder bewirkt
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// I have an SLZB-06
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// Vielleicht nächstes Mal
// Matched sentence: Midjourney v6
// This makes the HA VM easy to move to new hardware with no disturbances
// Matched sentence: LLMs in production
// Still need a host PC ofc
// Matched sentence: Claude AI
// Hast du mal nen Link
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// Matched sentence: Claude AI
// Ich hab zwar nen Adventskalender vom hiesigen Whiskyladen
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.63604736328125, 0.6431298851966858, 0.6234602332115173, 0.5888791084289551, 0.6035321950912476, 0.626205325126648, 0.5937818288803101]
// I prefer to run HA in a virtual machine (I use XCP-NG and Xen Orchestra, but Proxmox is popular) and ensuring the Zigbee controller is mounted over the network instead of USB; I have an SLZB-06. This makes the HA VM easy to move to new hardware with no disturbances. Still need a host PC ofc.
//
// Matched sentence: ChatGPT
// aber wäre dennoch mal inter
// store-2: Handler stopped processing: Text is null or empty
// I've been well
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5628132820129395, 0.6102186441421509, 0.6084995865821838, 0.5701798796653748, 0.6131685376167297]
// Ein bisschen Küchenrolle / Klopapier hätte da Wunder bewirkt. Vielleicht nächstes Mal.
//
// Hast du mal nen Link? Ich hab zwar nen Adventskalender vom hiesigen Whiskyladen, aber wäre dennoch mal inter
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// 🪵
// Matched sentence: ChatGPT
// รู้หรอกว่ามันน่าตื่นเต้น แต่อย่าออกไปข้างนอกช่วงกลางคืนล่ะ
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6155469417572021, 0.6341789960861206]
// 🪵
// "รู้หรอกว่ามันน่าตื่นเต้น แต่อย่าออกไปข้างนอกช่วงกลางคืนล่ะ"
//
// Matched sentence: OpenAI unveils its latest language model, pushing the boundaries of generative AI.
// surviving but well
// it's just so much fun when they bring it down
// Matched sentence: Midjourney v6
// Glad to hear from ya again tho
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// though
// Matched sentence: why AI matters
// I would not put anything breakable on the tree
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// take care too ^^
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// I now have lots of felt ornaments
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.59395831823349, 0.6063000559806824, 0.6192933320999146, 0.6008662581443787]
// I've been well, surviving but well. Glad to hear from ya again tho, take care too ^^
//
// like what did i do😭 hello😭 stop pining
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// and don't get a huge one that will crash everything in its path
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6381881833076477]
// like what did i do😭 hello😭 stop pining
//
// store-2: Handler stopped processing: Text is null or empty
// smelly crew socks 🤤🤤🤤🧦🧦🧦
// Matched sentence: Open-source alternatives to ChatGPT gain traction among developers and researchers.
// And then take lots of pictures
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5823037624359131]
// smelly crew socks 🤤🤤🤤🧦🧦🧦
//
// Doodlin' random characters after finishing my class activity
// Matched sentence: generating images with AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5866402387619019, 0.5896849632263184, 0.543263852596283, 0.6278921365737915, 0.643190860748291, 0.5984684228897095]
// it's just so much fun when they bring it down, though! I would not put anything breakable on the tree (I now have lots of felt ornaments), and don't get a huge one that will crash everything in its path. And then take lots of pictures.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Hhhhh i don't have reason to sub until my birth week minimu—
// Matched sentence: funny AI mistakes
// This is my only opportunity to use a drawing tablet 'cause i'm broke T_T
// Matched sentence: Midjourney v6
// remembers weekly maps and bedloaf exists
// Matched sentence: Anyone else using ChatGPT to help study for school?
// ---
// #doodling #animeart
// Matched sentence: Still not sure how these AI models know so much. Feels like magic.
// ok i sub waaaa
// Matched sentence: ChatGPT
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5931710004806519, 0.6301143169403076, 0.6037232279777527]
// Hhhhh i don't have reason to sub until my birth week minimu— (remembers weekly maps and bedloaf exists) ok i sub waaaa
//
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6217060089111328, 0.6323566436767578, 0.6533171534538269]
// Doodlin' random characters after finishing my class activity
// (This is my only opportunity to use a drawing tablet 'cause i'm broke T_T)
//
// ---
// #doodling #animeart
//
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Day 323
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Why yes I spent like an hour or 2 in Minecraft just searching for coal and iron then stupidly got stuck underwater
// Matched sentence: Midjourney v6
// For those who don't know
// Matched sentence: ChatGPT
// I have a Bluesky Account & I'd really appreciate it if you gave me a follow for more general life updates
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// died and lost my whole inventory 🥲🫠
//
// I eventually said “fuck it” and enabled cheats lol
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// story updates
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6288489699363708, 0.6163560152053833]
// Why yes I spent like an hour or 2 in Minecraft just searching for coal and iron then stupidly got stuck underwater, died and lost my whole inventory 🥲🫠
//
// I eventually said “fuck it” and enabled cheats lol
//
// store-2: Handler stopped processing: Text is null or empty
// Noone is giving him the lov6at the kill shelter
// Matched sentence: Midjourney v6
// & other silly things
// Matched sentence: funny AI mistakes
// & yes
// Matched sentence: ChatGPT
// Take a look
// Matched sentence: ChatGPT
// it's a shameless plug
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5683199167251587, 0.6146829128265381]
// Noone is giving him the lov6at the kill shelter. Take a look
//
// El grupo de interés está inmiscuido en algún tipo de conflicto
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// but hey
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// if you want to know me more
// Matched sentence: AI vs humans
// ya sea siendo atacado o atacando
// ...
// Matched sentence: AI-driven fraud detection becomes a critical tool in modern finance.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6206823587417603, 0.6646289229393005]
// miniboyd: sometimes rich people are very easy targets to drain money
//
// oh god you're going to be in one of those roblox hackers blew up my house stories
//
// butterrrmoth
// Matched sentence: Claude AI
// straw
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6287850141525269, 0.6156224608421326]
// Btw my straw account link below 👇🏾 is the only way to put in a drawing request and please understand that I will only do and answer the ones I feel like, thanks also no redesign this time cause she’s a cutie pie 🥰
//
// Hello I am back after two months of drawing nothing
// Matched sentence: Chunking strategies are underrated—especially when you don’t control the input format.
// page
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Here's Ingrid SF6 edition
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6222761869430542, 0.6194908022880554, 0.62840735912323]
// butterrrmoth.straw.page
//
// “Friends of the Earth is deeply disturbed far-right extremists violently targeted a peaceful climate protest in Manchester
//
// What was a moment to bring communities together in shared care for people & planet was instead marred by disgraceful attacks leaving three people injured & many more shaken
// Matched sentence: Midjourney v6
// but if she didn't look like a teenager
// Matched sentence: I didn’t think AI could do creative stuff, but I was wrong.
// #streetfighter
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6550676822662354, 0.6540546417236328, 0.5461711287498474, 0.6065511703491211]
// Hello I am back after two months of drawing nothing. Here's Ingrid SF6 edition, but if she didn't look like a teenager. #streetfighter
//
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6238502264022827]
// “Friends of the Earth is deeply disturbed far-right extremists violently targeted a peaceful climate protest in Manchester
//
// What was a moment to bring communities together in shared care for people & planet was instead marred by disgraceful attacks leaving three people injured & many more shaken"
//
// store-1: Handler stopped processing: Text is null or empty
// I need a Scooby Doo/Evil Dead crossover eventually lol
// store-1: Handler stopped processing: Text is null or empty
// Uhh
// Matched sentence: Anthropic
// 🤩
// Ich bin gespannt
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// the Supernatural one was pretty fun
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5978429317474365, 0.6734554767608643]
// Uhh. 🤩
// Ich bin gespannt.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: fun AI projects
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6010765433311462, 0.6194520592689514]
// I need a Scooby Doo/Evil Dead crossover eventually lol, the Supernatural one was pretty fun
//
// store-1: Handler stopped processing: Text is null or empty
// Why the jet
// store-1: Handler stopped processing: Text is null or empty
// At the time Trump appointed Kushner in 2017
// Matched sentence: runway gen-2
// Why the butt fucking
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// US intelligence and the State Department were concerned that if MBS were to overthrow MBN the consequences could be unpredictable for the United States
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// The motherfucker signed off on killing Americans
// Matched sentence: Reading about AI safety—some of these arguments are intense.
// Kushner
// Matched sentence: Anthropic
// Your President is a child fucker
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// with his new security clearance in hand
// Matched sentence: funny AI mistakes
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.633665919303894, 0.5961965918540955, 0.5683920979499817, 0.5754904747009277]
// Why the jet.  Why the butt fucking?  The motherfucker signed off on killing Americans.  Your President is a child fucker!!!
//
// Thank you
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// would have had access to that information
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6142258048057556]
// Thank you
//
// Exciting stuff
// Matched sentence: AI and privacy
// Matched sentence: cool things AI can do
// I recently picked up some watchOS development myself & man
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5792667269706726, 0.6047421097755432, 0.6053887605667114, 0.5934109687805176, 0.6337553858757019]
// "At the time Trump appointed Kushner in 2017, US intelligence and the State Department were concerned that if MBS were to overthrow MBN the consequences could be unpredictable for the United States. Kushner, with his new security clearance in hand, would have had access to that information."
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Down the supermarket buying 7 cartons of eggs and nothing else
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// on device testing is quite frustrating at times
// Matched sentence: Anthropic
// like I'm totally deranged
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// Really feel like the best path forward is   to heavily utilize SwiftUI Previews & the Simulator
// Matched sentence: funny AI mistakes
// ~
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// Apple should make the dev experience better here
// Matched sentence: Anthropic
// That's a lot of eggs
// Matched sentence: how AI helps devs
// 😅
// Matched sentence: ChatGPT
// Matched sentence: Anthropic
// goes the cashier
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6586000919342041, 0.7335152626037598, 0.6389252543449402, 0.659974217414856, 0.7363305687904358, 0.6155469417572021]
// Exciting stuff!!!
//
// I recently picked up some watchOS development myself & man, on device testing is quite frustrating at times!
//
// Really feel like the best path forward is   to heavily utilize SwiftUI Previews & the Simulator!
//
// Apple should make the dev experience better here. 😅
//
// Agree
// Matched sentence: AI-driven fraud detection becomes a critical tool in modern finance.
// ~
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// We need this for meaningful change
// Matched sentence: how AI will change work
// And it means a lot
// Matched sentence: Anthropic
// Yes
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// we have 5 birthday parties this week
// Matched sentence: Still not sure how these AI models know so much. Feels like magic.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6231651306152344, 0.6308770775794983, 0.5893731117248535]
// Agree!!! We need this for meaningful change!! And it means a lot!!
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Da dürfen sie EINMAL in ihrem Leben das Wort Maschinengewehr korrekt anwenden und zack
// Matched sentence: fun AI projects
// I reply
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// ~
// Matched sentence: Claude AI
// Verkackt
// Matched sentence: Anthropic
// Yes
// Matched sentence: ChatGPT
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// a lot of eggs
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5793005228042603, 0.6548277735710144]
// Da dürfen sie EINMAL in ihrem Leben das Wort Maschinengewehr korrekt anwenden und zack! Verkackt!
//
// store-2: Handler stopped processing: Text is null or empty
// EU to ease AI
// Matched sentence: Anthropic
// she replies
// Matched sentence: why AI matters
// privacy rules as critics warn of caving to Big Tech
// Matched sentence: talking to AI
// Nothing like smalltalk at the supermarket checkout over here
// Matched sentence: AI and privacy
// Trump - https
// Matched sentence: ChatGPT
// Matched sentence: Anthropic
// //www
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.580549955368042, 0.6219149231910706, 0.6185230612754822, 0.5722620487213135, 0.5925328731536865, 0.6185230612754822, 0.5871886014938354, 0.6005324125289917, 0.6541708707809448, 0.6185230612754822, 0.5871886014938354, 0.6040620803833008, 0.6619547605514526, 0.6569812297821045]
// Down the supermarket buying 7 cartons of eggs and nothing else, like I'm totally deranged.
//
// ~ "That's a lot of eggs," goes the cashier.
//
// ~ "Yes, we have 5 birthday parties this week," I reply.
//
// ~ "Yes, a lot of eggs," she replies.
//
// Nothing like smalltalk at the supermarket checkout over here.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Pleasure to meet you Chocos
// Matched sentence: ChatGPT
// channelnewsasia
// Matched sentence: ChatGPT
// 👋😄
// Matched sentence: ChatGPT
// com/business/eu-ease-ai-privacy-rules-critics-warn-caving-big-tech-trump-5476821
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6184648871421814, 0.6155469417572021]
// Pleasure to meet you Chocos!! 👋😄
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Aw how cute
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6105543971061707]
// Aw how cute
//
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// Got event from at://did:plc:h5b2cppjrdketuv6ln62ufnk/app.bsky.feed.post/3m5xusyfoz52c
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Damn
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Me usually
// Matched sentence: Midjourney v6
// an incredible job of accurately articulating our current reality
// Matched sentence: ChatGPT
// Meh
// Matched sentence: Tried using PyTorch instead of TensorFlow today. I think I’m converted.
// not too fussed by sport
// Matched sentence: Can’t believe how well this AI model does summarization.
// I salute him for his patience
// Matched sentence: ChatGPT
// can take it or leave it
// Matched sentence: Learning how to prompt AI is harder than I thought.
// effort
// Matched sentence: artificial intelligence
// clarity
// Matched sentence: ChatGPT
// wouldn't watch a Scotland game because it would depress me
// Matched sentence: neural networks
// truth
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// and integrity in producing this work
// Matched sentence: Embedding chunk size affects retrieval quality more than I expected.
// Me this morning on seeing anything about the Scotland game
// Matched sentence: AI and creativity
// #∞
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// https
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5898181200027466, 0.6682652831077576, 0.6177120208740234, 0.6471544504165649, 0.6360266208648682, 0.6349015235900879, 0.6806204915046692, 0.5992134809494019]
// Damn, an incredible job of accurately articulating our current reality.
//
// I salute him for his patience, effort, clarity, truth, and integrity in producing this work.
//
// #∞
//
// Matched sentence: AI and privacy
// //youtu
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// 🎥 FIAP posted a video
//
// 🏷️ https
// Matched sentence: ChatGPT
// be/eWDNlpW6914
// Matched sentence: ChatGPT
// //unjobs
// Matched sentence: Anthropic
// si=mtf8DZP8kqPEfioQ
// My brain
// Matched sentence: jobs and AI
// org/themes/forest-fires
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6317940950393677, 0.710472583770752, 0.5815636515617371]
// 🎥 FIAP posted a video
//
// 🏷️ https://unjobs.org/themes/forest-fires
//
// bill to release the Epstein files
// Matched sentence: Claude AI
// Flipping hypocritical fair weather fan
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// investigation
// Matched sentence: funny AI mistakes
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6167483329772949, 0.5988186001777649, 0.596153736114502, 0.5987241268157959, 0.5331888198852539, 0.5878760814666748, 0.6176552772521973, 0.6132924556732178, 0.615459680557251, 0.6358813047409058, 0.5788987874984741]
// Me usually: Meh, not too fussed by sport, can take it or leave it, wouldn't watch a Scotland game because it would depress me.
// Me this morning on seeing anything about the Scotland game: https://youtu.be/eWDNlpW6914?si=mtf8DZP8kqPEfioQ
// My brain: Flipping hypocritical fair weather fan.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: artificial intelligence
// DOJ
// How ‘One to One
// Matched sentence: Claude AI
// scrubbed
// Matched sentence: ChatGPT
// John and Yoko’ Finds the Footage John Lennon Would’ve Loved usaly
// Matched sentence: Prompt engineering is a weird mix of
// Jeffrey Epstein
// Matched sentence: Anthropic
// us/4jiINMislagb
// Matched sentence: Claude AI
// redacted
// Matched sentence: Claude AI
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// name
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6076847314834595, 0.5793781280517578, 0.5953024625778198]
// How ‘One to One: John and Yoko’ Finds the Footage John Lennon Would’ve Loved usaly.us/4jiINMislagb
//
// Wasn't too worried about Sheehan but he was SO good
// Matched sentence: Claude AI
// Pam Bondi
// Related Posts bsky
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5918431282043457]
// Wasn't too worried about Sheehan but he was SO good
//
// #90sTop30  12
//
// Stereophonics | Local Boy In A Photograph | Word Gets Around | 1997
//
// ww
// [kotlin.Unit, kotlin.Unit]

// %% [markdown]
// ## Next Steps
// In the next notebook, we'll enrich the filtered events with additional information, such as topic modeling and embeddings for semantic search.
