// %% [markdown]
// # Filtering JetStream Events

// %% [markdown]
// In this notebook, we'll filter events from the Redis Stream that we created in the previous notebook. We'll use a combination of techniques to filter the events:
//
// 1. Deduplication using Redis Bloom Filter to avoid processing the same event multiple times
// 2. Content-based filtering using a machine learning model to identify software-related posts
// 3. Storing filtered events in Redis for further processing
//
// Redis Bloom Filter is a probabilistic data structure that allows us to check if an element is in a set. It's very memory efficient and has a constant time complexity for both insertion and lookup operations. The trade-off is that it can have false positives, but the probability of false positives can be controlled by the size of the filter.
//
// Machine learning models can be used to classify text into different categories. In this notebook, we'll use a pre-trained zero-shot classification model to classify posts as software-related or not.

// %% [markdown]
// ## Consuming from Redis Streams

// %% [markdown]
// ### Model Redis Streams Event
// In this section, we'll define a data class to represent the events stored in the Redis Stream. This model will be used to deserialize the events from the stream.

// %% [markdown]
// ### Creating a Redis Client
// Create a Jedis client to connect to Redis. This is a reusable client that can be used to interact with Redis Streams.

// %% [markdown]
// ### Creating a Consumer Group
// Create a consumer group to read from the Redis Stream. A consumer group allows multiple consumers to read from the same stream without duplicating the work. Each consumer in the group will receive a different subset of the messages.
//
// A consumer group can be created in Redis with the XGROUP CREATE command:
//
// `XGROUP CREATE streamName groupName id [MKSTREAM]`
//
// To create a consumer group in this notebook, we will encapsulate the command in a function. The function will take the stream name and the group name as parameters.

// %%
%use coroutines

// %%
import redis.clients.jedis.StreamEntryID
import dev.raphaeldelio.*

fun createConsumerGroup(streamName: String, consumerGroupName: String) {
    try {
        jedisPooled.xgroupCreate(streamName, consumerGroupName, StreamEntryID("0-0"), true)
    } catch (_: Exception) {
        println("Group already exists")
    }
}

// %%
createConsumerGroup("jetstream", "printer-example")

// %% [markdown]
// ### Reading from the Stream
// Create a reusable function to read from the stream. This function will read from the stream and return a list of entries. It uses the XREADGROUP command to read from the stream as part of a consumer group:
//
// `XREADGROUP GROUP groupName consumerName COUNT count BLOCK blockTime streamName id`
//
// The command will be encapsulated in a function that takes the stream name, consumer group name, consumer name, and count as parameters. The function will return a list of entries.

// %%
import redis.clients.jedis.params.XReadGroupParams
import redis.clients.jedis.resps.StreamEntry

fun readFromStream(
    streamName: String,
    consumerGroup: String,
    consumer: String,
    count: Int
): List<Map.Entry<String, List<StreamEntry>>> {
    return jedisPooled.xreadGroup(
        consumerGroup,
        consumer,
        XReadGroupParams().count(count),
        mapOf(
            streamName to StreamEntryID.XREADGROUP_UNDELIVERED_ENTRY
        )
    ) ?: emptyList()
}

// %% [markdown]
// ### Acknowledging Messages
// Create a function to acknowledge the message. This is important to let Redis know that the message has been processed successfully, so it won't be delivered to other consumers in the group.
//
// This is done by using the XACK command:
//
// `XACK streamName groupName id`
//
// The command will be encapsulated in a lambda function that takes the stream name, consumer group name, and entry as parameters. The function will acknowledge the message by calling the XACK command.

// %%
fun ackFunction(): (streamName: String, consumerGroup: String, entry: StreamEntry) -> Unit {
    return { streamName, consumerGroup, entry ->
        jedisPooled.xack(
            streamName,
            consumerGroup,
            entry.id
        )
    }
}

// %% [markdown]
// ### Consuming the Stream
// Create a reusable function to consume the stream.
//
// This function implements a pipeline pattern where each event is processed sequentially by a series of handlers. If any handler returns false, the processing stops for that event.
//
// After processing the event, the function acknowledges the message using the ack function.

// %%
import kotlinx.coroutines.*

fun consumeStream(
    streamName: String,
    consumerGroup: String,
    consumer: String,
    handlers: List<(Event) -> Pair<Boolean, String>>,
    ackFunction: ((String, String, StreamEntry) -> Unit),
    count: Int = 1,
    limit: Int = 5
) {
    var lastMessageTime = System.currentTimeMillis()
    var consumed = 0

    while (consumed < limit) {
        val entries = readFromStream(streamName, consumerGroup, consumer, count)
        val allEntries = entries.flatMap { it.value }
        allEntries.map { entry ->
            consumed++
            val event = Event.fromMap(entry)

            for (handler in handlers) {
                val (shouldContinue, message) = handler(event)
                ackFunction(streamName, consumerGroup, entry)

                if (!shouldContinue) {
                    println("$consumer: Handler stopped processing: $message")
                    break
                }
            }
        }

        if (allEntries.isEmpty()) {
            val now = System.currentTimeMillis()
            if (now - lastMessageTime >= 2_000) {
                println("$consumer: No new messages for 2 seconds. Stopping.")
                break
            }
        }
    }

}

// %% [markdown]
// To test the consumeStream function, we'll create a simple handler that prints the event's URI.

// %%
val printUri: (Event) -> Pair<Boolean, String> = {
    println("Got event from ${it.uri}")
    Pair(true, "OK")
}

// %%
runBlocking {
    consumeStream(
        streamName = "jetstream",
        consumerGroup = "printer-example",
        consumer ="printer-1",
        handlers = listOf(printUri),
        ackFunction = ackFunction(),
        count = 1,
        limit = 500
    )
}
// Out:
// Got event from at://did:plc:tz5ykftv7i4uowym33cmey4m/app.bsky.feed.post/3lpy74bea3s2l
// Got event from at://did:plc:gipeuijaannaburxm6voyuf7/app.bsky.feed.post/3lpy75f6rkc2s
// Got event from at://did:plc:tpc42zt2y25vzh4a2djx5tvo/app.bsky.feed.post/3lpy75f7s2526
// Got event from at://did:plc:xfkk7zpf5czqz52qbizqr5tj/app.bsky.feed.post/3lpy65uq2hk2e
// Got event from at://did:plc:ftedet2hx7eru6du5rae63js/app.bsky.feed.post/3lpy75f73pc23
// Got event from at://did:plc:annmh2aamt3ctc2gubsvi6dj/app.bsky.feed.post/3lpy75fms6f2d
// Got event from at://did:plc:vwbjoq5c54l325p5ync72is6/app.bsky.feed.post/3lpy75fdsok27
// Got event from at://did:plc:vwbjoq5c54l325p5ync72is6/app.bsky.feed.post/3lpy75fimy227
// Got event from at://did:plc:vwbjoq5c54l325p5ync72is6/app.bsky.feed.post/3lpy75fipvs27
// Got event from at://did:plc:dwfbgsqwdsps4aobupgrb553/app.bsky.feed.post/3lpy75fiabs2l
// Got event from at://did:plc:dzetpmp4nf3g2iretw2mb72m/app.bsky.feed.post/3lpy75fhnq22r
// Got event from at://did:plc:ou4lljlduhupgbk5izv4dtpz/app.bsky.feed.post/3lpy75e5h5c2j
// Got event from at://did:plc:7ia5gyyqv2will5wxhrdey5h/app.bsky.feed.post/3lpy
// Got event from at://did:plc:btycmnuozhr4frmwc5rnbd6c/app.bsky.feed.post/3lpy75eonwc2f
// Got event from at://did:plc:fvwfzpx2zb3sycesjfl64v3b/app.bsky.feed.post/3kutzfwjclc2h
// printer-1: No new messages for 2 seconds. Stopping.

// %% [markdown]
// ## Semantic Classifier
// In this section, we'll use a vector similarity search to filter posts based on their content.
// We'll use a embed a list of references and classify the posts based on their similarity to the references.
// If the post is similar to the references, it will be classified as artificial-intelligence-related.

// %% [markdown]
// ### Including Spring AI Redis Vector Store
// The Redis Vector Store is a Spring AI module that allows you to store and retrieve vectors in Redis. It uses the Redis Vector Search feature to perform similarity searches on the vectors.

// %%
@file:DependsOn("org.springframework.ai:spring-ai-redis-store:1.0.0")
@file:DependsOn("org.springframework.ai:spring-ai-transformers:1.0.0")

// %% [markdown]
// ### Initializing an embedding model
// The embedding model is used to convert text into vectors. The Redis Vector Store uses the embedding model to store and retrieve vectors in Redis.
//
// The Transformers Embedding Model provided by Spring AI uses all-minilm-l6-v2 model by default which has 384 dimensions.
//
// The model is loaded from the Hugging Face Hub and can be used to convert text into vectors.

// %%
import org.springframework.ai.transformers.TransformersEmbeddingModel

val embeddingModel = TransformersEmbeddingModel()
embeddingModel.setModelResource("https://huggingface.co/sentence-transformers/all-mpnet-base-v2/resolve/main/onnx/model.onnx?download=true")
embeddingModel.setTokenizerResource("https://huggingface.co/sentence-transformers/all-mpnet-base-v2/raw/main/tokenizer.json")
embeddingModel.afterPropertiesSet()

// %% [markdown]
// ### Creating the store (and the index in Redis)
// By creating an index in Redis, we can use the Redis Vector Search feature to perform similarity searches on the vectors.

// %%
import org.springframework.ai.vectorstore.redis.RedisVectorStore
import org.springframework.ai.vectorstore.redis.RedisVectorStore.MetadataField
import redis.clients.jedis.search.Schema.FieldType
import dev.raphaeldelio.jedisPooled

val redisVectorStore = RedisVectorStore.builder(jedisPooled, embeddingModel)
    .indexName("classifierIdx")
    .contentFieldName("text")
    .embeddingFieldName("textEmbedding")
    .prefix("classifier:")
    .initializeSchema(true)
    .vectorAlgorithm(RedisVectorStore.Algorithm.FLAT)
    .build()
redisVectorStore.afterPropertiesSet()

// %% [markdown]
// ### Storing the references as vectors
//
// The references are stored in Redis as vectors. The vectors are created using the embedding model and stored in the Redis Vector Store.

// %%
import kotlinx.serialization.json.Json
import org.springframework.ai.document.Document
import java.io.File
import java.util.UUID

val references = Json.decodeFromString<List<String>>(File("resources/filtering-examples.json").readText())

fun storeFilterDocumentsInRedis(references: List<String>) {
    val documents = references.map { text ->
        createFilterDocument(text)
    }

    redisVectorStore.add(documents)
}

fun createFilterDocument(text: String): Document {
    return Document(
        UUID.randomUUID().toString(),
        text,
        mapOf(
            "text" to text,
        )
    )
}

storeFilterDocumentsInRedis(references)

// %% [markdown]
// ### Creating a Classification Function
// Now we'll create a function to classify text using the model.
//
// The function takes a text as input and returns a classification output. The classification output contains the probabilities for each candidate label.

// %%
import ai.djl.modality.nlp.translator.ZeroShotClassificationOutput
import org.springframework.ai.vectorstore.SearchRequest

fun classify(post: String): List<Double> {
    //val cleanedPost = removeUrls(post)
    return breakSentenceIntoClauses(post).map { clause ->
        println(clause)
        (redisVectorStore.similaritySearch(
            SearchRequest.builder()
                .topK(1)
                .query(clause)
                .build()
        )?.map {
            println("Matched sentence: ${it.text}")
            it.score ?: 0.0
        } ?: emptyList())
    }.flatten()
}

// %%
classify("Redis is a great tool for building applied AI systems because it's a Vector Database")
// Out:
// Redis is a great tool for building applied AI systems because it's a Vector Database
// Matched sentence: best AI tools right now
// [0.8059492111206055]

// %%
classify("I'm here at KotlinConf, I can't stand people talking about AI anymore.")
// Out:
// I'm here at KotlinConf
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// I can't stand people talking about AI anymore
// Matched sentence: why AI matters
// [0.6877487897872925, 0.8056651949882507]

// %%
classify("Redis is a great tool for building distributed systems")
// Out:
// Redis is a great tool for building distributed systems
// Matched sentence: RAG architectures are emerging as the go-to solution for enterprise search systems.
// [0.6799676418304443]

// %%
classify("Santos is the best city of Brazil.")
// Out:
// Santos is the best city of Brazil
// Matched sentence: Claude AI
// [0.575647234916687]

// %% [markdown]
// Optimizer for finding the best threshold for the classification function: https://github.com/redis-developer/redis-ai-resources/blob/main/python-recipes/semantic-router/01_routing_optimization.ipynb

// %% [markdown]
// ### Creating a Filter Handler
// Now we'll create a handler that filters events based on their content.
//
// The handler uses the classification function to determine if a post is software-related.
//
// If the post is not software-related, the handler returns false, which stops the processing of the event.

// %%
fun breakSentenceIntoClauses(sentence: String): List<String> {
    return sentence.split(Regex("""[!?,.:;]+"""))
        .filter { it.isNotBlank() }.map { it.trim() }
}

fun removeUrls(text: String): String {
    return text.replace(Regex("""(?:https?:\/\/)?(?:www\.)?[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}(\/\S*)?"""), "")
        .replace(Regex("""@\w+"""), "")
        .replace(Regex("""\s+"""), " ")
        .trim()
}

// %%
val filter: (Event) -> Pair<Boolean, String> = { event ->
    if (event.text.isNotBlank() && event.langs.contains("en") && event.operation != "delete") {
        val classification = classify(event.text)
        if (classification.any { it > 0.75 }) {
            Pair(true, "OK")
        } else {
            Pair(false, "Not a post related to artificial intelligence: Score: ${classification} \n${event.text}\n")
        }
    } else {
        Pair(false, "Text is null or empty")
    }
}

// %% [markdown]
// ## Storing Filtered Events
// In this section, we'll store the filtered events in Redis for further processing.

// %% [markdown]
// ### Storing Events in Redis
// Now we'll create a handler that stores events in Redis. The handler stores the event as a hash in Redis, with the key being the event's URI.

// %%
val storeEvent: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.hset("post:" + event.uri.replace("at://did:plc:", ""), event.toMap())
    Pair(true, "OK")
}

// %% [markdown]
// ### Adding Filtered Events to a New Stream
// Finally, we'll create a handler that adds filtered events to a new stream. This allows other consumers to process only the filtered events, rather than having to filter the events themselves.

// %%
import redis.clients.jedis.params.XAddParams

val addFilteredEventToStream: (Event) -> Pair<Boolean, String> = { event ->
    jedisPooled.xadd(
        "filtered-events",
        XAddParams.xAddParams().id(StreamEntryID.NEW_ENTRY),
        event.toMap()
    )
    Pair(true, "OK")
}

// %%
createConsumerGroup("jetstream", "store-example")

// %% [markdown]
// ## Putting It All Together
// Now we'll put all the pieces together to create a complete pipeline for filtering events from the Redis Stream.
//
// In this example we create two consumers that will process the same stream.
// - By doing that, we can scale the processing of the events by adding more consumers to the group.
// - Redis will make sure that each consumer will receive different messages.

// %%
runBlocking {
        listOf(
            async(Dispatchers.IO) {
                consumeStream(
                    streamName = "jetstream",
                    consumerGroup = "store-example",
                    consumer = "store-1",
                    handlers = listOf(
                        filter,
                        printUri,
                        storeEvent,
                        addFilteredEventToStream
                    ),
                    ackFunction = ackFunction(),
                    count = 1,
                    limit = 400
                )
            },
            async(Dispatchers.IO) {
                consumeStream(
                    streamName = "jetstream",
                    consumerGroup = "store-example",
                    consumer = "store-2", // Different consumer
                    handlers = listOf(
                        filter,
                        printUri,
                        storeEvent,
                        addFilteredEventToStream
                    ),
                    ackFunction = ackFunction(),
                    count = 1,
                    limit = 400
                )
            }
        ).awaitAll()
}
// Out:
// store-1: Handler stopped processing: Text is null or empty
// seems like i am pretty late to it
// Source
// Matched sentence: Meta's latest open-source vision model challenges proprietary alternatives.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6083656549453735]
// Source
//
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// goes in 5 days already
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// It’s absolutely crazy
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6365300416946411, 0.6068365573883057]
// seems like i am pretty late to it! goes in 5 days already.
//
// Because God forbid there’s something wrong with your personality to why she’s not into you
// Matched sentence: Concerns grow over hallucinations in large language models used in production systems.
// but it’s also kind of always existed
// Matched sentence: Transformers have taken over every corner of AI now.
// Just depends on the era
// Matched sentence: why AI gets things wrong
// Which leads into the “she never chooses the nice guys” narrative aka feeling entitled because you think you’re better than the “jock” even tho you still suck
// Matched sentence: Latency during multi-turn inference is killing my use case. Thinking about caching strategies.
// but unfortunately it keeps evolving and changing and that’s for all genders
// Matched sentence: AI is going to change completely over the next decade.
// There was a time that as a man if you had a nice car/ job then you’re guaranteed a woman and if you didn’t get one she’s stuck up
// Matched sentence: how AI helps devs
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5835373401641846, 0.5771585702896118]
// Because God forbid there’s something wrong with your personality to why she’s not into you. Which leads into the “she never chooses the nice guys” narrative aka feeling entitled because you think you’re better than the “jock” even tho you still suck.
//
// But that’s just like 2 random reasons an incel might feel entitled
// Matched sentence: bias in AI models
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6349631547927856, 0.602014422416687, 0.5491111874580383, 0.6408134698867798, 0.5598104000091553]
// It’s absolutely crazy, but it’s also kind of always existed. Just depends on the era, but unfortunately it keeps evolving and changing and that’s for all genders.
// There was a time that as a man if you had a nice car/ job then you’re guaranteed a woman and if you didn’t get one she’s stuck up
//
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// Same guys that swore Stippers legit loved them
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// #BBCBreakfast turns itself into a ReformUK party broadcast by reporting verbatim on policy ideas which are in no manifesto and which - with their tax cuts - they couldn't follow through on anyway
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// Can now talk to an SW on OF or any app and fall into a par-asocial relationship and swear it’s real
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Then feel entitled to them because they spent money and time on them
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Just like his orange pal in the US
// Matched sentence: Claude AI
// Farage will gift and grift for his posh boy mates
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5846496224403381, 0.564629077911377, 0.646210789680481, 0.5883209705352783]
// But that’s just like 2 random reasons an incel might feel entitled. Same guys that swore Stippers legit loved them. Can now talk to an SW on OF or any app and fall into a par-asocial relationship and swear it’s real.
// Then feel entitled to them because they spent money and time on them.
//
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// dmSnrHS2HqDb1w3z4r2T
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.62421715259552, 0.5829702615737915, 0.5937608480453491]
// #BBCBreakfast turns itself into a ReformUK party broadcast by reporting verbatim on policy ideas which are in no manifesto and which - with their tax cuts - they couldn't follow through on anyway.
// Just like his orange pal in the US, Farage will gift and grift for his posh boy mates.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// The ‘we aren’t as bad as them’ has been the Dem playbook for decades
// When in fact they were just as beholden to their corporate donors as the republicans
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6528908610343933]
// macro: dmSnrHS2HqDb1w3z4r2T
//
// store-2: Handler stopped processing: Text is null or empty
// @ctaylor5
// Matched sentence: ChatGPT
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social
//
// I beg you
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// with just slightly less pious hypocrisy
// Matched sentence: ChatGPT
// I am extremely hungry and haven't eaten for four days
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// Our children are hungry too
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5773252844810486, 0.609738826751709]
// The ‘we aren’t as bad as them’ has been the Dem playbook for decades
// When in fact they were just as beholden to their corporate donors as the republicans, with just slightly less pious hypocrisy.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Any small amount can help buy food
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// 4nxJrIwUJXD12TBkajpd
// Matched sentence: why AI matters
// Please don't ignore this urgent call for help
// Matched sentence: GPT-4
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6604822874069214]
// macro: 4nxJrIwUJXD12TBkajpd
//
// Using machines for violent colonialism
// Matched sentence: Prompt engineering is a weird mix of
// Donate and share
// Matched sentence: Anthropic
// Palmer Luckey made his fortune with VR headsets
// Matched sentence: ChatGPT
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// app/profile/111a
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// founding Oculus as a teen
// Matched sentence: AI and privacy
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6507084369659424, 0.6055374145507812, 0.6538421511650085, 0.5942201614379883, 0.5805346965789795, 0.5784114599227905, 0.6404358148574829, 0.6031996011734009, 0.6055374145507812, 0.6052013039588928]
// @ctaylor5.bsky.social
//
// I beg you, I am extremely hungry and haven't eaten for four days. Our children are hungry too. Any small amount can help buy food. Please don't ignore this urgent call for help.
// Donate and share .
// bsky.app/profile/111a...
//
// store-2: Handler stopped processing: Text is null or empty
// They’re going to be a disaster
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// Now he's focused on the future of warfare
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// But it’s what the people voted for…
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// developing autonomous weapons powered by AI for the U
// Matched sentence: Prompt injection is still a serious problem with user-generated queries.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6300233602523804, 0.5842113494873047]
// They’re going to be a disaster. But it’s what the people voted for…
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Love it
// Matched sentence: how to build with AI
// S
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Also the contrast between the blue and orange is great ^^ Well done 😇
// Matched sentence: artificial intelligence
// military and its allies
// Matched sentence: GPT-4
// youtu
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6139477491378784, 0.5731621980667114]
// Love it! Also the contrast between the blue and orange is great ^^ Well done 😇
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: deep learning
// be/bWEXnph1ElI
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Feed
// Matched sentence: ChatGPT
// Slow Boring
// Matched sentence: Anthropic
// Got event from at://did:plc:jv4btbksfgdzpkhqzxxmxaz7/app.bsky.feed.post/3lpy75bkqns22
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: cool things AI can do
// By
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// They all by the looks of it
// Matched sentence: machine learning
// Ben Krauss on Saturday
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5909175872802734]
// They all by the looks of it
//
// Matched sentence: Claude AI
// May 24
// Yes
// Matched sentence: Midjourney v6
// 2025
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// because Christianity is all about ‘manliness’
// Matched sentence: AI is going to change completely over the next decade.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6565663814544678, 0.6274099946022034, 0.6284480094909668, 0.5859788656234741, 0.5958870649337769, 0.6563780903816223]
// Feed: "Slow Boring"
// By: Ben Krauss on Saturday, May 24, 2025
//
// I never thought I would hate watching West Wing
// but I do despise  hope the golly be lucky we're pluck attitude on wild fictional display
// Its a great story of what could have been sans the drama for drama the basics were pretty damn good
// but still thinking about what is happening in reality sux
// Matched sentence: Anthropic
// apparently -  www
// Matched sentence: Anthropic
// bbc
// Matched sentence: ChatGPT
// co
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// uk/news/article
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5871886014938354, 0.5579479932785034, 0.6137135028839111, 0.6157971024513245, 0.5912232398986816, 0.665834367275238]
// Yes, because Christianity is all about ‘manliness’, apparently -  www.bbc.co.uk/news/article...
//
// fuck
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5873647928237915]
// I never thought I would hate watching West Wing
// but I do despise  hope the golly be lucky we're pluck attitude on wild fictional display
// Its a great story of what could have been sans the drama for drama the basics were pretty damn good
// but still thinking about what is happening in reality sux
//
// Matched sentence: Claude AI
// turns out im just stupid 💔
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6012458205223083]
// fuck
//
//
//
// fuck x2
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// Matched sentence: runway gen-2
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6402382254600525]
// turns out im just stupid 💔
//
//
//
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5968796014785767]
// fuck x2
//
//
//
// macro
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// raUVLMbQGuDTjXoeaeRg
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// Bkx3ARCuJ6eLdZ1SIwRs
// Matched sentence: runway gen-2
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6467643976211548]
// macro: raUVLMbQGuDTjXoeaeRg
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.5995216965675354]
// macro: Bkx3ARCuJ6eLdZ1SIwRs
//
// rappel
// store-1: Handler stopped processing: Text is null or empty
// feel for him his luck is so horrendously bad 😭 was expecting the pit stops to fuck up his race
// Matched sentence: ChatGPT
// on est en pleine privatisation de la RATP
// Matched sentence: funny AI mistakes
// not this
// Matched sentence: Claude AI
// un des derniers services publics qui était encore épargné
// Matched sentence: Hugging Face is the GitHub of machine learning.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5953537821769714, 0.6060181856155396]
// feel for him his luck is so horrendously bad 😭 was expecting the pit stops to fuck up his race, not this
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6589458584785461, 0.6615800261497498, 0.6176313161849976]
// rappel : on est en pleine privatisation de la RATP, un des derniers services publics qui était encore épargné
//
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// VrHTy64FIygauQWq8Y3W
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// AJz91RtHzQQ5Eiu9qX2y
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.627458393573761]
// macro: VrHTy64FIygauQWq8Y3W
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: ChatGPT
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// lLQghFh4tlu8tC4RKnoY
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6051152348518372]
// macro: AJz91RtHzQQ5Eiu9qX2y
//
// He's utterly clueless
// Matched sentence: why AI gets things wrong
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6252617835998535]
// He's utterly clueless.
//
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6389400959014893]
// macro: lLQghFh4tlu8tC4RKnoY
//
// I most certainly am
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// youtu
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.601683497428894]
// I most certainly am
//
// Matched sentence: deep learning
// be/VlTdRZe4XZw
// store-2: Handler stopped processing: Text is null or empty
// Justin Webb will describe this as a powerful and very funny speech before moving on to lecture us about Biden's lack of sentience
// Matched sentence: ChatGPT
// One talented talented man
// Matched sentence: AI and creativity
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6296432018280029, 0.6200611591339111, 0.6229394674301147]
// youtu.be/VlTdRZe4XZw?...
//
// One talented talented man
//
// #パソコン・周辺機器#ディスプレイ#特価
//
// 🌻🌼
// 【VGP 2025 金賞】LG ゲーミング モニター UltraGear OLED 27GS95QE・・・
//
// 🔥-34%￥98
// Matched sentence: Can’t believe how well this AI model does summarization.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6372714042663574]
// Justin Webb will describe this as a powerful and very funny speech before moving on to lecture us about Biden's lack of sentience.
//
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// h1RwABFw1gaejNufRfuP
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6333207488059998]
// macro: h1RwABFw1gaejNufRfuP
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// This also made me realize how badly I want to have my companion idea implemented into starfield
// Matched sentence: ChatGPT
// 391🔥
// 💍984pt
// Matched sentence: ChatGPT
// 1%
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// I still want of make a companion based off of me and voiced but with a cool fleshed out quest
// Matched sentence: Researchers explore new methods for evaluating LLM reliability and truthfulness.
// 💍
//
// 残り20以上
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.612480640411377, 0.6341789960861206, 0.5978790521621704, 0.5966566801071167]
// #パソコン・周辺機器#ディスプレイ#特価
//
// 🌻🌼
// 【VGP 2025 金賞】LG ゲーミング モニター UltraGear OLED 27GS95QE・・・
//
// 🔥-34%￥98,391🔥
// 💍984pt(1%)💍
//
// 残り20以上
//
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// armor
// @mahalo11
// Matched sentence: artificial intelligence
// weapons the whole nine yards
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social
// I beg you
// Matched sentence: runway gen-2
// maybe one day
// Matched sentence: ChatGPT
// I am extremely hungry and haven't eaten for 3 days
// Matched sentence: cool things AI can do
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6657346487045288, 0.6543138027191162, 0.6273970007896423, 0.6231722831726074, 0.6047992706298828]
// This also made me realize how badly I want to have my companion idea implemented into starfield ( I still want of make a companion based off of me and voiced but with a cool fleshed out quest, armor, weapons the whole nine yards, maybe one day)
//
// La figurine 1/7
// Matched sentence: Claude AI
// ALTER
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// Our children are hungry too
// Matched sentence: how AI will change work
// de Elbe
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Any small amount can help buy food
// Matched sentence: Claude AI
// Pure-Hearted Bad Girl Ver
// Matched sentence: why AI matters
// Please don't ignore this urgent call for help
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// 「Azur Lane」est disponible en précommande via le shop français Ixu Deviance
// Matched sentence: Prompt engineering is a weird mix of
// Donate and share
// bsky
// Matched sentence: Hugging Face announces new partnership to accelerate AI adoption in government projects.
// app/profile/88ha
// Matched sentence: Claude AI
// ・ bit
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6358605623245239, 0.6055374145507812, 0.6538421511650085, 0.5684696435928345, 0.5805346965789795, 0.5784114599227905, 0.6404358148574829, 0.6311015486717224, 0.6125302314758301]
// @mahalo11.bsky.social
// I beg you, I am extremely hungry and haven't eaten for 3 days. Our children are hungry too. Any small amount can help buy food. Please don't ignore this urgent call for help.
// Donate and share
// bsky.app/profile/88ha...
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Anakin paused as he heard her familiar voice
// Matched sentence: Chunking strategies are underrated—especially when you don’t control the input format.
// ly/4dxofzO
// ・ -5% avec le code
// Matched sentence: how to prompt AI
// He slowly turned from the strangers he was with
// Matched sentence: Claude AI
// Moepop”
//
// #ALTER #AzurLane #アズールレーン
// Matched sentence: AI and privacy
// not expecting to see his old padawan
// Matched sentence: Claude AI
// Snips
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6638845205307007, 0.6477257013320923, 0.6645438075065613, 0.5904015302658081, 0.6325722932815552, 0.6485503315925598, 0.6354254484176636, 0.6212360858917236]
// La figurine 1/7 (ALTER) de Elbe: Pure-Hearted Bad Girl Ver.「Azur Lane」est disponible en précommande via le shop français Ixu Deviance.
//
// ・ bit.ly/4dxofzO
// ・ -5% avec le code "Moepop”
//
// #ALTER #AzurLane #アズールレーン
//
// macro
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6385290622711182, 0.5815469026565552, 0.5846983194351196, 0.6045341491699219]
// Anakin paused as he heard her familiar voice.
// He slowly turned from the strangers he was with, not expecting to see his old padawan.
//
// "Snips?"
//
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// D2f9Q30nGLL8DovyWaT1
// Here's hoping one day it works
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6199923157691956]
// Here's hoping one day it works
//
// store-1: Handler stopped processing: Text is null or empty
// UPDATE
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6302022337913513]
// macro: D2f9Q30nGLL8DovyWaT1
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Jumping subjects a bit
// Matched sentence: Midjourney v6
// One missile fired by Houthis in Yemen
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// I will ALWAYS love Galaxy Quest
// Matched sentence: runway gen-2
// successfully intercepted
// Matched sentence: Transformers have taken over every corner of AI now.
// Never give up
// Matched sentence: ChatGPT
// No physical injuries reported
// Matched sentence: why AI gets things wrong
// Never surrender
// Matched sentence: Reading about AI safety—some of these arguments are intense.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6164315938949585, 0.5582931041717529, 0.607084333896637, 0.583940327167511]
// UPDATE: One missile fired by Houthis in Yemen, successfully intercepted. No physical injuries reported.
//
// macro
// Matched sentence: Reading about AI safety—some of these arguments are intense.
// #GalaxyQuest #StarWars #NeverGiveUpNeverSurrender
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// sFnhVhZXYDrGz5zRmgob
// Matched sentence: Transformers have taken over every corner of AI now.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.650648295879364, 0.6120478510856628, 0.6051778793334961, 0.6137455105781555, 0.6276107430458069]
// Jumping subjects a bit, I will ALWAYS love Galaxy Quest! "Never give up! Never surrender!"
//
// #GalaxyQuest #StarWars #NeverGiveUpNeverSurrender
//
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6378259658813477]
// macro: sFnhVhZXYDrGz5zRmgob
//
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// #GNXTour Kendrick & Sza 👏🏾👏🏾👏🏾 fantastic show
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// I absolutely dare them to publish an editorial backing the onshoring of iPhone manufacture
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6216553449630737]
// #GNXTour Kendrick & Sza 👏🏾👏🏾👏🏾 fantastic show
//
// store-1: Handler stopped processing: Text is null or empty
// リス似のハム
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// & suggesting that Trump should launch the return of factory jobs by personally assembling the first All-American iPhone in public
// Matched sentence: runway gen-2
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5872995257377625]
// リス似のハム
//
// No
// Matched sentence: Anyone else using ChatGPT to help study for school?
// Leadership has curled up into a corner
// Matched sentence: AI agents that plan and execute tasks are the next big thing.
// delicately manipulating all those tiny screws with his teeny fingers
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// still not comprehending how Peter Dutton lost so badly
// Matched sentence: Trying to understand how AI learns. Feels like teaching a kid but faster.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6323499083518982, 0.6307428479194641, 0.629761815071106]
// I absolutely dare them to publish an editorial backing the onshoring of iPhone manufacture, & suggesting that Trump should launch the return of factory jobs by personally assembling the first All-American iPhone in public, delicately manipulating all those tiny screws with his teeny fingers.
//
// QtipsANON
// Matched sentence: funny AI mistakes
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5870121717453003, 0.648485004901886, 0.5782618522644043]
// No.
//
// Leadership has curled up into a corner, still not comprehending how Peter Dutton lost so badly.
//
// Same
// Matched sentence: ChatGPT
// Here's hoping Ron wins
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// It was obvious at that point the fix was in to help the 🍊🤡
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6609779000282288, 0.5721991658210754]
// QtipsANON. Here's hoping Ron wins!
//
// store-2: Handler stopped processing: Text is null or empty
// That's frightening 😳
// Matched sentence: funny AI mistakes
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6106341481208801, 0.644973635673523]
// Same. It was obvious at that point the fix was in to help the 🍊🤡
//
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6480139493942261]
// That's frightening 😳
//
// store-2: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// Vm6ohNrUdKTyBUoubMdP
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// mxd6WNq4AiW7zmf5yezX
// Matched sentence: Midjourney v6
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6430467367172241]
// macro: Vm6ohNrUdKTyBUoubMdP
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6119006276130676]
// macro: mxd6WNq4AiW7zmf5yezX
//
// store-1: Handler stopped processing: Text is null or empty
// no exactly
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Training neural nets feels like dark magic half the time.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6092416048049927]
// no exactly
//
// store-2: Handler stopped processing: Text is null or empty
// goodnight everyone
// remember to be kind 🫶
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5827717781066895]
// goodnight everyone
// remember to be kind 🫶
//
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// OoUEWLwrT5zRLsP7LIJD
// store-2: Handler stopped processing: Text is null or empty
// It’ll be just like British Rail
// Matched sentence: AI is going to change completely over the next decade.
// except Great 👍
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.619990885257721]
// macro: OoUEWLwrT5zRLsP7LIJD
//
// store-1: Handler stopped processing: Text is null or empty
// Its one of the like 6 films from the last 5 years I have seen
// Matched sentence: funny AI mistakes
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6135141849517822, 0.6213239431381226]
// It’ll be just like British Rail, except Great 👍
//
// store-2: Handler stopped processing: Text is null or empty
// 🧵💥 Russia
// Matched sentence: ChatGPT
// Ukrainian drones struck the Migalovo Military Transport Aviation base in Tver region
// Matched sentence: Midjourney v6
// admittedly because a friend worked on it
// Matched sentence: Tried coding with GitHub Copilot. It’s like pair programming with a robot.
// 165km northwest of the Kremlin
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6608500480651855, 0.6467338800430298]
// Its one of the like 6 films from the last 5 years I have seen (admittedly because a friend worked on it)
//
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: runway gen-2
// Russia air defenses kept trying to shoot down their own transport aircraft trying to flee the area after taking off from this same base
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// FV9lZ1Auo6Heoj060bUi
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6211925745010376]
// macro: FV9lZ1Auo6Heoj060bUi
//
// Book of Dave - Will Self
// Matched sentence: why AI gets things wrong
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5978653430938721, 0.5817602872848511, 0.5529487133026123, 0.580241322517395]
// 🧵💥 Russia: Ukrainian drones struck the Migalovo Military Transport Aviation base in Tver region, 165km northwest of the Kremlin.
// Russia air defenses kept trying to shoot down their own transport aircraft trying to flee the area after taking off from this same base.
//
// Yes found mine the other day funnily enough and was wondering what to do with them
// Matched sentence: Midjourney v6
// read it on release
// Matched sentence: Midjourney v6
// thought I'd have another go at his books
// Matched sentence: If you're not using embeddings for search yet, you're missing out.
// Felt like tempting fate to throw them away
// Matched sentence: Anyone else using ChatGPT to help study for school?
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6102801561355591, 0.6354222297668457, 0.607871413230896]
// Book of Dave - Will Self, read it on release... thought I'd have another go at his books.
//
// @mleroi
// Matched sentence: funny AI mistakes
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5977809429168701, 0.570404052734375]
// Yes found mine the other day funnily enough and was wondering what to do with them. Felt like tempting fate to throw them away!
//
// store-2: Handler stopped processing: Text is null or empty
// I don’t know how it’s going to be paid for
// Matched sentence: ChatGPT
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social
// Life has become unbearable in Gaza 😥💔
// Matched sentence: artificial intelligence
// and I’m sure there will be all sorts of press/Tory/Reform screeching when we find out
// Matched sentence: ChatGPT
// no water
// Matched sentence: Anthropic
// no food
// Matched sentence: Anthropic
// no safety
// Matched sentence: AI regulation is back in the spotlight after high-profile model misuse cases.
// But always assumed that the reason that the cap lifting was being delayed was that the funds simply weren’t there
// Matched sentence: Reading about AI safety—some of these arguments are intense.
// Every day feels like a fight to stay alive
// Matched sentence: AI-powered tools are showing promise in early diagnosis and treatment planning.
// Please
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// Is that a simplistic view
// Matched sentence: Claude AI
// if you can
// Matched sentence: deep learning
// donate or share
// Matched sentence: bias in AI models
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6027170419692993, 0.5925655364990234, 0.5775963068008423, 0.6276999711990356]
// I don’t know how it’s going to be paid for, and I’m sure there will be all sorts of press/Tory/Reform screeching when we find out. But always assumed that the reason that the cap lifting was being delayed was that the funds simply weren’t there.
//
// Is that a simplistic view?
//
// Nahh its all lies
// Matched sentence: ChatGPT
// Your help can bring light into our darkest days
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// I use blendable pixel brushes on procreate im a fraud fufufu ♡ but I also do classic pixel art too
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// app/profile/anas
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.641861081123352, 0.6055374145507812, 0.5969853401184082, 0.557090163230896, 0.6031772494316101, 0.6617873907089233, 0.605993926525116, 0.5975733399391174, 0.6072514057159424, 0.5887618064880371, 0.5947440266609192, 0.6055374145507812, 0.6192156076431274]
// @mleroi.bsky.social
// Life has become unbearable in Gaza 😥💔. no water, no food, no safety. Every day feels like a fight to stay alive. Please, if you can, donate or share. Your help can bring light into our darkest days.
// bsky.app/profile/anas...
//
// ❄️ should we go to sleep
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// ☆
//
// Thanks for being sweet to me
// Matched sentence: ChatGPT
// yes
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// my star ♡
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// will we
// Matched sentence: Fine-tuned a model on my own dataset today. Hugging Face makes it so easy.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6954114437103271, 0.6915848851203918, 0.6095631122589111, 0.6141402721405029]
// Nahh its all lies, I use blendable pixel brushes on procreate im a fraud fufufu ♡ but I also do classic pixel art too! ☆
//
// Thanks for being sweet to me, my star ♡
//
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: the future of Artificial Intelligence
// remains to be seen
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Stop
// Matched sentence: the future of Artificial Intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6118099689483643, 0.5871886014938354, 0.6255671977996826, 0.6086102724075317]
// ❄️ should we go to sleep? yes. will we? remains to be seen...
//
// Matched sentence: machine learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6085594892501831]
// Stop
//
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Probably because it used to be really difficult to get properly ripe tomatoes in Northern Europe
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// XyggTqloJaDzPVNdtBHw
// Matched sentence: Benchmarking MPNET vs E5 for semantic search on small documents.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5512939691543579]
// Probably because it used to be really difficult to get properly ripe tomatoes in Northern Europe.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.673613429069519]
// macro: XyggTqloJaDzPVNdtBHw
//
// store-1: Handler stopped processing: Text is null or empty
// macro
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Fuck the BBC
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// h1DraKkbnNXsYLFYmjAr
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5819283723831177]
// Fuck the BBC!
//
// store-2: Handler stopped processing: Text is null or empty
// my phone is always out of storage
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6208886504173279]
// macro: h1DraKkbnNXsYLFYmjAr
//
// And don't say it can't happen because time travel
// Matched sentence: Is it normal that AI sometimes just makes stuff up?
// cons of the old iphone model
// Matched sentence: The impact of large-scale fine-tuning raises concerns.
// so every week or two i spin the wheel and delete an app
// Matched sentence: AI is going to change completely over the next decade.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6040393114089966]
// And don't say it can't happen because time travel!
//
// charcoal sketch by e
// Matched sentence: AI and creativity
// e
// Matched sentence: Heard about LangChain but not sure when I’d actually need it.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5658624172210693, 0.6129428148269653, 0.6063195466995239]
// my phone is always out of storage (cons of the old iphone model) so every week or two i spin the wheel and delete an app
//
// store-2: Handler stopped processing: Text is null or empty
// Matched sentence: Anthropic
// cummings
// store-2: Handler stopped processing: Text is null or empty
// #AlphabetChallenge
// #WeekUforUp
// Day 7
// See
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6517720222473145, 0.6352030038833618, 0.6407350897789001]
// charcoal sketch by e. e. cummings
//
// Feed
// Matched sentence: ChatGPT
// Slow Boring
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// Antony
// Matched sentence: cool things AI can do
// By
// Matched sentence: Claude AI
// that revels long o’ the nights
// Matched sentence: machine learning
// Ben Krauss on Saturday
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// Is
// Matched sentence: Claude AI
// Matched sentence: Claude AI
// notwithstanding up
// May 24
// Matched sentence: Prompt engineering is a weird mix of
// Shakespeare - Julies Caesar
// Matched sentence: Midjourney v6
// 2025
// Matched sentence: AI is going to change completely over the next decade.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6565663814544678, 0.6274099946022034, 0.6284480094909668, 0.5859788656234741, 0.5958870649337769, 0.6563780903816223]
// Feed: "Slow Boring"
// By: Ben Krauss on Saturday, May 24, 2025
//
// store-1: Handler stopped processing: Text is null or empty
// Matched sentence: AI for writing
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6409944891929626, 0.657270073890686, 0.5837103128433228, 0.6009332537651062, 0.5998860597610474, 0.6044673919677734]
// #AlphabetChallenge
// #WeekUforUp
// Day 7
// See! Antony, that revels long o’ the nights.
// Is, notwithstanding up.
// Shakespeare - Julies Caesar
//
// macro
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Wordle 1
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// DfmHoKb2mwc7PaISg1ir
// Matched sentence: NLP models
// 436 3/6
//
// ⬜🟨⬜🟨⬜
// 🟩🟩🟩⬜⬜
// 🟩🟩🟩🟩🟩
//
// 1st 2 guesses were how I would describe politicians then I went to @racheljs
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6164263486862183]
// macro: DfmHoKb2mwc7PaISg1ir
//
// me scoping out the early reviews of history of sound
// Matched sentence: Midjourney v6
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// bsky
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6216741800308228]
// me scoping out the early reviews of history of sound:
//
// So jealous of everyone at the old Galaxy*
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social clue to fit a word
// Matched sentence: runway gen-2
// the Powerstation
// Matched sentence: NLP models
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6694978475570679, 0.6034423112869263, 0.6055374145507812, 0.6447022557258606]
// Wordle 1,436 3/6
//
// ⬜🟨⬜🟨⬜
// 🟩🟩🟩⬜⬜
// 🟩🟩🟩🟩🟩
//
// 1st 2 guesses were how I would describe politicians then I went to @racheljs.bsky.social clue to fit a word
//
// Really don’t know what to say
// Matched sentence: runway gen-2
// Auckland New Zealand
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// I just miss talking to you
// Matched sentence: Building a side project with LangChain + OpenAI APIs. Loving it so far.
// for Snarky Puppy tonight
//
// * see how old I am
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6388776302337646, 0.6463296413421631]
// Really don’t know what to say. I just miss talking to you.
//
// macro
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.60842365026474, 0.6656876802444458, 0.5792790651321411, 0.5977393388748169]
// So jealous of everyone at the old Galaxy*, the Powerstation, Auckland New Zealand, for Snarky Puppy tonight
//
// * see how old I am
//
// Nice
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// DsPQLfe7jRa48vzabL49
// Matched sentence: cool things AI can do
// Thanks for the link
// Matched sentence: NVIDIA’s latest GPUs cater specifically to generative model training at scale.
// It's going straight onto my to-read list
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6177537441253662]
// macro: DsPQLfe7jRa48vzabL49
//
// But Donald was going to end the war “on day 1”
//
// “I’m not a puppet
// Matched sentence: NLP is moving so fast I can’t keep up anymore.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6104391813278198, 0.5629959106445312, 0.6236392259597778]
// Nice! Thanks for the link. It's going straight onto my to-read list.
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Extremadura #Extremadura #AEMET #Weather #WeatherForecast
// Matched sentence: Learning how to prompt AI is harder than I thought.
// you’re the puppet”
//
// Donald is #PutinsBitch
//
// #SlavaUkraini
//
// bbc
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5969732999801636]
// Extremadura #Extremadura #AEMET #Weather #WeatherForecast
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// youtu
// Matched sentence: smart chatbots
// com/news/article
// Matched sentence: deep learning
// be/2WVCgIc8FtY
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5909392237663269, 0.5934332609176636, 0.6564711332321167]
// But Donald was going to end the war “on day 1”
//
// “I’m not a puppet, you’re the puppet”
//
// Donald is #PutinsBitch
//
// #SlavaUkraini
//
// bbc.com/news/article...
//
// macro
// Matched sentence: ChatGPT
// #24 映画「PERFECT DAYS」でも出た幸田文「木」の紹介 / 幸田文『木』その１
// ...
// What idiot shows up at West Point , no less, wearing a baseball cap?
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// NO WAY is this the head Invisible account with 1
// Matched sentence: AI-driven fraud detection becomes a critical tool in modern finance.
// 500 members
// Matched sentence: smart chatbots
// completely impossible
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// Art done by me on MS Paint
// Matched sentence: deep learning
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6170825958251953, 0.629060685634613, 0.6094855070114136]
// NO WAY is this the head Invisible account with 1,500 members. completely impossible
//
// store-2: Handler stopped processing: Text is null or empty
// I’m with Bruce on that too
// Matched sentence: Used an AI tool to generate images for my blog. Pretty fun.
// so get memed on friends
// Matched sentence: Claude AI
// he’s just a fantastic fella isn’t he
// Matched sentence: Started playing with Hugging Face models. No idea what I’m doing but it’s cool.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6811333894729614, 0.7043808102607727, 0.6263153553009033]
// I have stickers for friends/mutuals when I see ya'll at OFFKAI \o/ cause why not?
//
// Art done by me on MS Paint, so get memed on friends
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Claude AI
// And a an unbelievable performer
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// omas9MmXuQfof8P7qWGz
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5878090858459473, 0.5970932245254517, 0.5977311134338379]
// I’m with Bruce on that too , he’s just a fantastic fella isn’t he . And a an unbelievable performer
//
// ⠀
// ⠀⠀i  love  robin  but  she  can't  cook
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.642703652381897]
// macro: omas9MmXuQfof8P7qWGz
//
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// Yup
// Matched sentence: Claude AI
// and  demetrius  is  always  brewing  some  new  atrocity  in  his  lab  to  eat
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.597702145576477]
// Yup !
//
// Just seen this -amazing amazing
// Matched sentence: Training neural nets feels like dark magic half the time.
// no  thanks
// Matched sentence: Just tried out the new GPT model—it's wild how good it is at coding.
// So exciting - congratulations @ronanhession
// Matched sentence: ChatGPT
// ⠀
// Matched sentence: Just built my first chatbot using AI. It’s super basic but I’m proud.
// bsky
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5920245051383972, 0.614951491355896, 0.5951130390167236, 0.6155469417572021]
// ⠀
// ⠀⠀i  love  robin  but  she  can't  cook,  and  demetrius  is  always  brewing  some  new  atrocity  in  his  lab  to  eat.  no  thanks  !
// ⠀
//
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Santé 😉🎶🍻
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social
// Matched sentence: Claude AI
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6303696632385254]
// Santé 😉🎶🍻
//
// Matched sentence: Anthropic
// @ofmooseandmen
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Let's throw out the Dirty
// Matched sentence: I asked ChatGPT to help me write an email and it kinda worked.
// bsky
// Matched sentence: Hugging Face is the GitHub of machine learning.
// social
// Matched sentence: Anthropic
// stale Tory Bath Water to save the Babies
// Matched sentence: Anthropic
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6397889852523804, 0.6202666759490967, 0.6055374145507812, 0.658962070941925, 0.6346081495285034, 0.6055374145507812, 0.658962070941925]
// Just seen this -amazing amazing!!! So exciting - congratulations @ronanhession.bsky.social ; @ofmooseandmen.bsky.social
//
// choices like
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5986438989639282, 0.5832401514053345]
// Let's throw out the Dirty, stale Tory Bath Water to save the Babies!
//
// Matched sentence: good AI use cases
// PISS NOW
// They kicked several people from their discord server 😔 because notably people aren’t happy with how they treated their characters nor how they behaved in general
// Matched sentence: ChatGPT
// HOLD IT
// Matched sentence: ChatGPT
// resulting in the death of billions is peak
// Matched sentence: Anthropic
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6229671835899353, 0.6321455240249634, 0.6237637996673584, 0.629052996635437]
// choices like [PISS NOW] [HOLD IT] resulting in the death of billions is peak
//
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6568571329116821]
// They kicked several people from their discord server 😔 because notably people aren’t happy with how they treated their characters nor how they behaved in general.
//
// macro
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// Hypocrisy
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// 7YPpKuWgpaUC7Y8BhsFT
// Matched sentence: Anthropic
// Their religion is a tool for power rather than teachings of Christ
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6491489410400391]
// macro: 7YPpKuWgpaUC7Y8BhsFT
//
// store-1: Handler stopped processing: Text is null or empty
// Time for some Valencia lore drop
// Matched sentence: Anthropic
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6376093626022339, 0.5428931713104248]
// Hypocrisy. Their religion is a tool for power rather than teachings of Christ.
//
// Cult following of sinners
// Matched sentence: LangChain gains traction as a key framework for building AI-powered applications.
// Valencia might be one of the youngest overlords in hell
// Matched sentence: Concerns grow over hallucinations in large language models used in production systems.
// demons
// Matched sentence: Anthropic
// hell orbs
// Matched sentence: LLMs are getting scary good. Anyone else worried about AI alignment?
// She d-ed in 2014 and grew up on tech and video games
// Matched sentence: Just realized model hallucinations go way up when you over-truncate context.
// and hellhounds alike
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// She’ became an overlord by betting
// Matched sentence: Thinking about how to integrate a RAG pipeline in our search system.
// Due to this she quickly cheated her way up to the top and became an overlord
// Matched sentence: funny AI mistakes
// and cheating
// Matched sentence: funny AI mistakes
// her way through multiple video game tournaments
// Matched sentence: funny AI mistakes
// Her powers include manipulating fights in her favor
// Matched sentence: Can’t believe how well this AI model does summarization.
// yes even hell has video games
// Matched sentence: Still not sure how these AI models know so much. Feels like magic.
// turning any room into a real video game
// Matched sentence: cool things AI can do
// and gained a 1/
// Matched sentence: cool things AI can do
// remotely hacking people’s gaming consoles
// Matched sentence: Trying to map HF Transformers output logits to classification scores manually. Painful but interesting.
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5983603000640869, 0.6095849871635437, 0.6138609647750854, 0.5896176695823669, 0.5994246006011963, 0.6018474102020264, 0.5689248442649841, 0.5790368914604187]
// Time for some Valencia lore drop! Valencia might be one of the youngest overlords in hell. She d-ed in 2014 and grew up on tech and video games. She’ became an overlord by betting, and cheating, her way through multiple video game tournaments (yes even hell has video games) and gained a 1/???
//
// Knowledge of every video game known to man
// Matched sentence: ChatGPT just helped me debug an issue I’ve been stuck on for hours.
// having a mass 2/
// Matched sentence: cool things AI can do
// and being able to complete games in 30 minutes
// Matched sentence: Midjourney v6
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5594896674156189, 0.617394208908081, 0.5746653079986572, 0.5810214281082153, 0.573804497718811, 0.6585339307785034, 0.6801278591156006, 0.6202706098556519, 0.5848410725593567]
// Cult following of sinners, demons, hell orbs, and hellhounds alike. Due to this she quickly cheated her way up to the top and became an overlord. Her powers include manipulating fights in her favor, turning any room into a real video game, remotely hacking people’s gaming consoles, having a mass 2/?
//
// CEO and his two colleagues noticed her quick and wanted her to join their team to be the fourth Vee
// Matched sentence: how AI helps devs
// She uses her hacking and jail breaking skills to manipulate gamers into needing to pay her to fix busted consoles or buy new consoles from which she heavily profits off of
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// However Valencia strongly hates the CEO and owner of the tech company so she passed up the chance
// Matched sentence: how AI helps devs
// A certain Tech 3/
// Matched sentence: The rise of AI startups is reshaping the landscape of software development.
// Eventually she will like him but not now
// Matched sentence: artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.681442379951477, 0.6476808786392212, 0.6463668346405029, 0.6977543830871582]
// Knowledge of every video game known to man, and being able to complete games in 30 minutes. She uses her hacking and jail breaking skills to manipulate gamers into needing to pay her to fix busted consoles or buy new consoles from which she heavily profits off of. A certain Tech 3/???
//
// She ran an underground bootlegging
// Matched sentence: how AI learns
// As for why she’s in hell… 4/
// Matched sentence: Trying to keep up with all the AI startups popping up right now.
// pirating
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// and jail breaking video game ring which is very very illegal where she lives and she got caught and ran from the law
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.638437032699585, 0.6316945552825928, 0.572022020816803, 0.5601067543029785]
// CEO and his two colleagues noticed her quick and wanted her to join their team to be the fourth Vee. However Valencia strongly hates the CEO and owner of the tech company so she passed up the chance. Eventually she will like him but not now. As for why she’s in hell… 4/????
//
// Led to another she was caught and shot on site
// Matched sentence: Experts debate the ethical implications of fine-tuning LLMs on user-generated content.
// Now she’s in hell running her empire from the comfort of her apartment
// Matched sentence: cool things AI can do
// While on the run she entered a video game contest under a false name and cheated her way to winning
// Matched sentence: The rise of AI startups is reshaping the landscape of software development.
// Anyways happy lore day Valencia you exist now
// Matched sentence: AI making stuff up
// One thing 5/
// Matched sentence: ChatGPT
// #Valenciahelluvaboss #helluvabossvalencia
// #helluvaboss #oc #helluvabossoc #helluvabossfanart
// Matched sentence: artificial intelligence
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5712372660636902, 0.5881144404411316, 0.5441117286682129, 0.5952327847480774, 0.5974908471107483]
// She ran an underground bootlegging, pirating, and jail breaking video game ring which is very very illegal where she lives and she got caught and ran from the law. While on the run she entered a video game contest under a false name and cheated her way to winning. One thing 5/????
//
// store-1: Handler stopped processing: Text is null or empty
// macro
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// vRfNq0jC6PUYdIQVLo3j
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.6134113073348999]
// macro: vRfNq0jC6PUYdIQVLo3j
//
// Matched sentence: Claude AI
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.5923749208450317, 0.5555446743965149, 0.5911357402801514, 0.6002575159072876]
// Led to another she was caught and shot on site. Now she’s in hell running her empire from the comfort of her apartment. Anyways happy lore day Valencia you exist now!
//
// #Valenciahelluvaboss #helluvabossvalencia
// #helluvaboss #oc #helluvabossoc #helluvabossfanart
//
// store-1: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// store-1: Handler stopped processing: Text is null or empty
// macro
// store-2: Handler stopped processing: Text is null or empty
// store-2: Handler stopped processing: Text is null or empty
// why can this stupid fucking dog touch the water but not me
// Matched sentence: Used AI to summarize a long article. Saved me a lot of time.
// wqNVhmBmtPAyyCi67pF0
// Matched sentence: why AI gets things wrong
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.593332052230835]
// why can this stupid fucking dog touch the water but not me
//
// store-2: Handler stopped processing: Text is null or empty
// But all the songs that were made for this shows were by the same studio no
// Matched sentence: ChatGPT
// store-1: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6743417978286743, 0.663949728012085]
// macro: wqNVhmBmtPAyyCi67pF0
//
// Agree
// Matched sentence: The new computer vision model from Meta is outperforming everything else.
// I do often
// Matched sentence: A new wave of generative AI tools is transforming the creative industry.
// Especially tariq alarabi turgan
// From Syria
// Matched sentence: Anyone else using ChatGPT to help study for school?
// Not this weeks but hubby bad way
// Matched sentence: Claude AI
// ⁠ ⁠╹⁠▽⁠╹⁠ ⁠
// Matched sentence: Anyone else getting hallucinations when querying long context in GPT-4?
// Hell I canvassed Fl last two elections
// Matched sentence: ChatGPT
// store-2: Handler stopped processing: Not a post related to artificial intelligence: Score: [0.6588226556777954, 0.5960711240768433, 0.6155469417572021]
// But all the songs that were made for this shows were by the same studio no ?
// Especially tariq alarabi turgan
// From Syria (⁠ ⁠╹⁠▽⁠╹⁠ ⁠)
//
// LOL
// Matche
// [kotlin.Unit, kotlin.Unit]

// %% [markdown]
// ## Next Steps
// In the next notebook, we'll enrich the filtered events with additional information, such as topic modeling and embeddings for semantic search.
